# %% [markdown]
# ## API AND DATA CLEANING

# %% [markdown]
# ### importing required libraries

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ### API IDEALISTA

# %% [markdown]
# ### loading excel_dataset from idealista

# %%
#Loading excel 
df=pd.read_csv("../input/idealista.csv")
df.head()
# Out:
#    propertyCode                                          thumbnail  \
# 0      94477419  https://img3.idealista.com/blur/WEB_LISTING/0/...
# 1      94477330  https://img3.idealista.com/blur/WEB_LISTING/0/...
# 2      94477212  https://img3.idealista.com/blur/WEB_LISTING/0/...
# 3      82312915  https://img3.idealista.com/blur/WEB_LISTING/0/...
# 4      94476388  https://img3.idealista.com/blur/WEB_LISTING/0/...
#
#   externalReference  numPhotos floor      price propertyType operation   size  \
# 0          60190176          2     1   114000.0         flat      sale   53.0
# 1       NOVAL ÁNGEL         42     1   319000.0         flat      sale   97.0
# 2         LORE-0767         10     2   496000.0         flat      sale  130.0
# 3         ch-422800         40     3  1340000.0         flat      sale  183.0
# 4        CHAMBERI 3          2    bj   290000.0         flat      sale   60.0
#
#    exterior  ...  priceByArea          detailedType  \
# 0     False  ...       2151.0  {'typology': 'flat'}
# 1      True  ...       3289.0  {'typology': 'flat'}
# 2     False  ...       3815.0  {'typology': 'flat'}
# 3      True  ...       7322.0  {'typology': 'flat'}
# 4     False  ...       4833.0  {'typology': 'flat'}
#
#                                       suggestedTexts hasPlan has3DTour has360  \
# 0  {'subtitle': 'Delicias, Madrid', 'title': 'Pis...   False     False  False
# 1  {'subtitle': 'Puerta del Ángel, Madrid', 'titl...   False     False  False
# 2  {'subtitle': 'Malasaña-Universidad, Madrid', '...   False     False  False
# 3   {'subtitle': 'El Viso, Madrid', 'title': 'Piso'}   False     False  False
# 4  {'subtitle': 'Nuevos Ministerios-Ríos Rosas, M...    True     False  False
#
#   hasStaging topNewDevelopment  \
# 0      False             False
# 1      False             False
# 2      False             False
# 3      False             False
# 4      False             False
#
#                                         parkingSpace  newDevelopmentFinished
# 0                                                NaN                     NaN
# 1                                                NaN                     NaN
# 2                                                NaN                     NaN
# 3  {'hasParkingSpace': True, 'isParkingSpaceInclu...                     NaN
# 4                                                NaN                     NaN
#
# [5 rows x 37 columns]

# %% [markdown]
# ### First visualizations

# %%
len(df)
# Out:
# 3800

# %%
df.columns
# Out:
# Index(['propertyCode', 'thumbnail', 'externalReference', 'numPhotos', 'floor',
#        'price', 'propertyType', 'operation', 'size', 'exterior', 'rooms',
#        'bathrooms', 'address', 'province', 'municipality', 'district',
#        'country', 'neighborhood', 'latitude', 'longitude', 'showAddress',
#        'url', 'distance', 'hasVideo', 'status', 'newDevelopment', 'hasLift',
#        'priceByArea', 'detailedType', 'suggestedTexts', 'hasPlan', 'has3DTour',
#        'has360', 'hasStaging', 'topNewDevelopment', 'parkingSpace',
#        'newDevelopmentFinished'],
#       dtype='object')

# %% [markdown]
# ### Selection only Madrid municipality

# %%
df.municipality.unique()
# Out:
# array(['Madrid', 'Leganés', 'Pozuelo de Alarcón', 'Getafe'], dtype=object)

# %%
df.operation.unique()
# Out:
# array(['sale'], dtype=object)

# %%
df=df[df.municipality=="Madrid"]

# %% [markdown]
# ### checking null and duplicated values

# %%
print("len df:",len(df))
# Out:
# len df: 3672

# %%
df.drop_duplicates()
# Out:
#       propertyCode                                          thumbnail  \
# 0         94477419  https://img3.idealista.com/blur/WEB_LISTING/0/...
# 1         94477330  https://img3.idealista.com/blur/WEB_LISTING/0/...
# 2         94477212  https://img3.idealista.com/blur/WEB_LISTING/0/...
# 3         82312915  https://img3.idealista.com/blur/WEB_LISTING/0/...
# 4         94476388  https://img3.idealista.com/blur/WEB_LISTING/0/...
# ...            ...                                                ...
# 3795      94296062  https://img3.idealista.com/blur/WEB_LISTING/0/...
# 3796      94295998                                                NaN
# 3797      94295874                                                NaN
# 3798      94295872                                                NaN
# 3799      94295853                                                NaN
#
#      externalReference  numPhotos floor      price propertyType operation  \
# 0             60190176          2     1   114000.0         flat      sale
# 1          NOVAL ÁNGEL         42     1   319000.0         flat      sale
# 2            LORE-0767         10     2   496000.0         flat      sale
# 3            ch-422800         40     3  1340000.0         flat      sale
# 4           CHAMBERI 3          2    bj   290000.0         flat      sale
# ...                ...        ...   ...        ...          ...       ...
# 3795         560091010         28    bj   182400.0         flat      sale
# 3796         560090031          0     5   320400.0         flat      sale
# 3797         560087421          0     1   136600.0         flat      sale
# 3798         560087420          0    bj   150100.0         flat      sale
# 3799         560087397          0    bj  1148900.0         flat      sale
#
#        size  exterior  ...  priceByArea          detailedType  \
# 0      53.0     False  ...       2151.0  {'typology': 'flat'}
# 1      97.0      True  ...       3289.0  {'typology': 'flat'}
# 2     130.0     False  ...       3815.0  {'typology': 'flat'}
# 3     183.0      True  ...       7322.0  {'typology': 'flat'}
# 4      60.0     False  ...       4833.0  {'typology': 'flat'}
# ...     ...       ...  ...          ...                   ...
# 3795  116.0     False  ...       1572.0  {'typology': 'flat'}
# 3796   73.0     False  ...       4389.0  {'typology': 'flat'}
# 3797   49.0     False  ...       2788.0  {'typology': 'flat'}
# 3798   51.0     False  ...       2943.0  {'typology': 'flat'}
# 3799  137.0     False  ...       8386.0  {'typology': 'flat'}
#
#                                          suggestedTexts hasPlan has3DTour  \
# 0     {'subtitle': 'Delicias, Madrid', 'title': 'Pis...   False     False
# 1     {'subtitle': 'Puerta del Ángel, Madrid', 'titl...   False     False
# 2     {'subtitle': 'Malasaña-Universidad, Madrid', '...   False     False
# 3      {'subtitle': 'El Viso, Madrid', 'title': 'Piso'}   False     False
# 4     {'subtitle': 'Nuevos Ministerios-Ríos Rosas, M...    True     False
# ...                                                 ...     ...       ...
# 3795  {'subtitle': 'Casco Histórico de Vallecas, Mad...   False     False
# 3796  {'subtitle': 'Prosperidad, Madrid', 'title': '...   False     False
# 3797  {'subtitle': 'Vista Alegre, Madrid', 'title': ...   False     False
# 3798  {'subtitle': 'Vista Alegre, Madrid', 'title': ...   False     False
# 3799  {'subtitle': 'El Viso, Madrid', 'title': 'Piso...   False     False
#
#      has360 hasStaging topNewDevelopment  \
# 0     False      False             False
# 1     False      False             False
# 2     False      False             False
# 3     False      False             False
# 4     False      False             False
# ...     ...        ...               ...
# 3795  False      False             False
# 3796  False      False             False
# 3797  False      False             False
# 3798  False      False             False
# 3799  False      False             False
#
#                                            parkingSpace  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3     {'hasParkingSpace': True, 'isParkingSpaceInclu...
# 4                                                   NaN
# ...                                                 ...
# 3795                                                NaN
# 3796                                                NaN
# 3797                                                NaN
# 3798                                                NaN
# 3799                                                NaN
#
#       newDevelopmentFinished
# 0                        NaN
# 1                        NaN
# 2                        NaN
# 3                        NaN
# 4                        NaN
# ...                      ...
# 3795                     NaN
# 3796                     NaN
# 3797                     NaN
# 3798                     NaN
# 3799                     NaN
#
# [3620 rows x 37 columns]

# %%
print("len df:",len(df))
#No había ningún valor duplicado
# Out:
# len df: 3672

# %%
def null_cols(db):
    nulls = df.isna().sum()
    return nulls[nulls > 0] / len(df) * 100
null_cols(df)
# Out:
# thumbnail                  1.007625
# externalReference         24.482571
# floor                      6.617647
# hasLift                    5.119826
# parkingSpace              77.995643
# newDevelopmentFinished    96.350763
# dtype: float64

# %%
#True=1; suma los 1
null_cols = df.isnull().sum()
null_cols
# Out:
# propertyCode                 0
# thumbnail                   37
# externalReference          899
# numPhotos                    0
# floor                      243
# price                        0
# propertyType                 0
# operation                    0
# size                         0
# exterior                     0
# rooms                        0
# bathrooms                    0
# address                      0
# province                     0
# municipality                 0
# district                     0
# country                      0
# neighborhood                 0
# latitude                     0
# longitude                    0
# showAddress                  0
# url                          0
# distance                     0
# hasVideo                     0
# status                       0
# newDevelopment               0
# hasLift                    188
# priceByArea                  0
# detailedType                 0
# suggestedTexts               0
# hasPlan                      0
# has3DTour                    0
# has360                       0
# hasStaging                   0
# topNewDevelopment            0
# parkingSpace              2864
# newDevelopmentFinished    3538
# dtype: int64

# %% [markdown]
# ### district column

# %%
df.district.unique()
# Out:
# array(['Arganzuela', 'Latina', 'Centro', 'Chamartín', 'Chamberí',
#        'Moratalaz', 'Tetuán', 'Carabanchel', 'Retiro', 'Vicálvaro',
#        'Fuencarral', 'San Blas', 'Puente de Vallecas',
#        'Barrio de Salamanca', 'Ciudad Lineal', 'Moncloa', 'Villaverde',
#        'Hortaleza', 'Villa de Vallecas', 'Usera'], dtype=object)

# %%
plt.figure(figsize=(16,4))

#sns.countplot(x=df.district)
ax = sns.countplot(x="district", data=df, palette='pastel' )
ax.set_xticklabels(ax.get_xticklabels(),  rotation=40, ha="right",fontsize=10)
plt.tight_layout() 

# Chart and axes titles
ax.set_title('Viviendas a la venta por distrito',fontsize = 18, fontweight='bold' )
ax.set_xlabel('Distrito', fontsize = 15)
ax.set_ylabel('Distrito count', fontsize = 15)

# show count (+ annotate)
for rect in ax.patches:
    ax.text (rect.get_x() + rect.get_width()  / 2,rect.get_height()+ 0.75,rect.get_height(),horizontalalignment='center', fontsize = 11)

plt.show()

# %%
##plt.figure(figsize=(16,4))

#ax = sns.countplot(x=df.district=="centro", palette='pastel', hue="neighborhood" )
#ax.set_xticklabels(ax.get_xticklabels(),  rotation=40, ha="right",fontsize=10)
#plt.tight_layout() 

# Chart and axes titles
#ax.set_title('Viviendas a la venta por distrito/barrio',fontsize = 18, fontweight='bold' )
#ax.set_xlabel('Distrito', fontsize = 15)
#ax.set_ylabel('Distrito count', fontsize = 15)

# %% [markdown]
# ### hasStaging column

# %%
df.hasStaging.unique()
#eliminaremos esta columna porque no contiene valores sobre si la casa tien Home Staging o no
# Out:
# array([False])

# %% [markdown]
# ### hasPlan, hasVideo, has360, has3DTour columns

# %%
#por el momento mantenemos estas columnas
df.hasPlan.unique()
# Out:
# array([False,  True])

# %%
df.hasVideo.unique()
# Out:
# array([False,  True])

# %%
df.has360.unique()
# Out:
# array([False,  True])

# %%
df.has3DTour.unique()
# Out:
# array([False,  True])

# %% [markdown]
# ### externalReference column

# %%
df.externalReference.unique()
#eliminaremos esta columna, la información que contiene carece de importancia
# Out:
# array(['60190176', 'NOVAL ÁNGEL', 'LORE-0767', ..., '560087421',
#        '560087420', '560087397'], dtype=object)

# %% [markdown]
# ### thumbnail column

# %%
df.thumbnail.unique()
#eliminaremos esta columna, la información que contiene carece de importancia
# Out:
# array(['https://img3.idealista.com/blur/WEB_LISTING/0/id.pro.es.image.master/53/9a/65/889949483.jpg',
#        'https://img3.idealista.com/blur/WEB_LISTING/0/id.pro.es.image.master/fc/e2/0c/889947745.jpg',
#        'https://img3.idealista.com/blur/WEB_LISTING/0/id.pro.es.image.master/d5/54/9f/889943840.jpg',
#        ...,
#        'https://img3.idealista.com/blur/WEB_LISTING/0/id.pro.es.image.master/b9/85/70/84189070.jpg',
#        'https://img3.idealista.com/blur/WEB_LISTING/0/id.pro.es.image.master/aa/a9/7d/884877709.jpg',
#        'https://img3.idealista.com/blur/WEB_LISTING/0/id.pro.es.image.master/e8/6c/e7/886703356.jpg'],
#       dtype=object)

# %%
df.columns
# Out:
# Index(['propertyCode', 'thumbnail', 'externalReference', 'numPhotos', 'floor',
#        'price', 'propertyType', 'operation', 'size', 'exterior', 'rooms',
#        'bathrooms', 'address', 'province', 'municipality', 'district',
#        'country', 'neighborhood', 'latitude', 'longitude', 'showAddress',
#        'url', 'distance', 'hasVideo', 'status', 'newDevelopment', 'hasLift',
#        'priceByArea', 'detailedType', 'suggestedTexts', 'hasPlan', 'has3DTour',
#        'has360', 'hasStaging', 'topNewDevelopment', 'parkingSpace',
#        'newDevelopmentFinished'],
#       dtype='object')

# %% [markdown]
# ### newDevelopment/status columns

# %%
df.status.unique()
# Out:
# array(['good', 'renew', 'newdevelopment'], dtype=object)

# %%
print("newDevelopment unique:",df.newDevelopment.unique())
print("topnewDevelopment unique:",df.topNewDevelopment.unique())
print("newDevelopmentFinished unique:",df.newDevelopmentFinished.unique())
# Out:
# newDevelopment unique: [False  True]
# topnewDevelopment unique: [False]
# newDevelopmentFinished unique: [nan True False]

# %% [markdown]
# #### Comprobar si estas columnas tienen los mismos datos

# %%
((df["newDevelopment"] == df["topNewDevelopment"]) & (df["newDevelopment"] == df["newDevelopmentFinished"])).value_counts()
# Out:
# False    3672
# dtype: int64

# %%
(df["newDevelopment"] == df["topNewDevelopment"]).value_counts()
#eliminaremos esta columna ya que contien los mismos valores que df.newDevelopment
# Out:
# True     3538
# False     134
# dtype: int64

# %%
(df["newDevelopment"] == df["newDevelopmentFinished"]).value_counts()
# Out:
# False    3669
# True        3
# dtype: int64

# %%
df["newDevelopmentFinished"].isnull().sum()
#eliminaremos esta columna ya que contien muchos valones nulos
# Out:
# 3538

# %% [markdown]
# #### plotting

# %%
plt.figure(figsize=(6,4))


ax = sns.countplot(x="newDevelopment", data=df, palette='pastel' )
ax.set_xticklabels(ax.get_xticklabels(),  rotation=40, ha="right",fontsize=10)
plt.tight_layout() 

# Chart and axes titles
ax.set_title('Viviendas nueva construcción o segunda mano',fontsize = 18, fontweight='bold' )
ax.set_xlabel('Segunda mano/ nueva construcción', fontsize = 15)
ax.set_ylabel('Count', fontsize = 15)

# show count (+ annotate)
for rect in ax.patches:
    ax.text (rect.get_x() + rect.get_width()  / 2,rect.get_height()+ 0.75,rect.get_height(),horizontalalignment='center', fontsize = 11)

plt.show() 

#La mayoría son de segunda mano

# %% [markdown]
# ### propertyType & detailedType columns

# %%
df.propertyType.unique()
#La principal oferta es de pisos
# Out:
# array(['flat', 'studio', 'penthouse', 'chalet', 'duplex'], dtype=object)

# %%
df.detailedType.unique()
# Out:
# array(["{'typology': 'flat'}",
#        "{'typology': 'flat', 'subTypology': 'studio'}",
#        "{'typology': 'flat', 'subTypology': 'penthouse'}",
#        "{'typology': 'chalet', 'subTypology': 'independantHouse'}",
#        "{'typology': 'flat', 'subTypology': 'duplex'}",
#        "{'typology': 'chalet', 'subTypology': 'terracedHouse'}",
#        "{'typology': 'chalet'}",
#        "{'typology': 'chalet', 'subTypology': 'semidetachedHouse'}"],
#       dtype=object)

# %%
plt.figure(figsize=(6,4))


ax = sns.countplot(x="propertyType", data=df, palette='pastel' )
ax.set_xticklabels(ax.get_xticklabels(),  rotation=40, ha="right",fontsize=10)
plt.tight_layout() 

# Chart and axes titles
ax.set_title('Tipo de vivienda a la venta',fontsize = 18, fontweight='bold' )
ax.set_xlabel('Tipo', fontsize = 15)
ax.set_ylabel('Count', fontsize = 15)

# show count (+ annotate)
for rect in ax.patches:
    ax.text (rect.get_x() + rect.get_width()  / 2,rect.get_height()+ 0.75,rect.get_height(),horizontalalignment='center', fontsize = 11)

plt.show()

# %% [markdown]
# ### neihborhood columns

# %%
df.neighborhood.unique()
#no vamos a ir a tanto detalle así que eliminaremos esta columna
# Out:
# array(['Delicias', 'Puerta del Ángel', 'Malasaña-Universidad', 'El Viso',
#        'Nuevos Ministerios-Ríos Rosas', 'Gaztambide', 'Vinateros',
#        'Cuatro Caminos', 'Vallehermoso', 'San Isidro', 'Aluche',
#        'Jerónimos', 'Valdebernardo - Valderribas', 'Niño Jesús',
#        'Buena Vista', 'Peñagrande', 'Simancas', 'Chueca-Justicia',
#        'San Diego', 'Fuente del Berro', 'Canillejas', 'Quintana',
#        'Salvador', 'Media Legua', 'Lucero', 'Los Cármenes', 'Valdezarza',
#        'Argüelles', 'Estrella', 'Lista', 'Numancia',
#        'Lavapiés-Embajadores', 'Palos de Moguer', 'Huertas-Cortes',
#        'Guindalera', 'Castellana', 'Los Rosales', 'Villaverde Alto',
#        'Amposta', 'Virgen del Cortijo - Manoteras', 'Recoletos', 'Goya',
#        'Canillas', 'Ventas', 'Valdebebas - Valdefuentes', 'Trafalgar',
#        'Santa Eugenia', 'Tres Olivos - Valverde',
#        'Casco Histórico de Vallecas', 'Abrantes', 'San Cristóbal',
#        'Vista Alegre', 'Ensanche de Vallecas - La Gavia',
#        '12 de Octubre-Orcasur', 'Palomeras sureste', 'Puerta Bonita',
#        'Almagro', 'Ventilla-Almenara', 'Acacias', 'Aravaca',
#        'Prosperidad', 'Casco Histórico de Vicálvaro', 'Valdemarín',
#        'Mirasierra', 'Palacio', 'Hellín', 'Pinar del Rey',
#        'Bernabéu-Hispanoamérica', 'Sol', 'Opañel', 'Valdeacederas',
#        'Zofío', 'Cuzco-Castillejos', 'Comillas', 'Palomas', 'Pilar',
#        'Concepción', 'Imperial', 'Bellas Vistas', 'La Paz', 'Ambroz',
#        'Portazgo', 'Costillares', 'San Pascual', 'Pacífico', 'Chopera',
#        'Ciudad Jardín', 'Almendrales', 'San Juan Bautista', 'Rosas',
#        'Pueblo Nuevo', 'Nueva España', 'Moscardó', 'Adelfas', 'Entrevías',
#        'Fontarrón', 'Campamento', 'Casa de Campo', 'Ciudad Universitaria',
#        'Arcos', 'Pradolongo', 'San Fermín', 'Arapiles', 'Berruguete',
#        'Butarque', 'Castilla', 'Montecarmelo', 'Ibiza', 'Sanchinarro',
#        'Palomeras Bajas', 'Legazpi', 'Águilas', 'Colina', 'Los Ángeles',
#        'Arroyo del Fresno', 'Conde Orgaz-Piovera', 'Las Tablas',
#        'Marroquina', 'Orcasitas', 'Apóstol Santiago',
#        'Pau de Carabanchel', 'Pavones', 'Cuatro Vientos', 'Atalaya',
#        'Fuentelarreina', 'Rejas'], dtype=object)

# %% [markdown]
# ### dropping first columns

# %% [markdown]
# * externalReference
# * thumbanail
# * detailedType
# * topNewDevelopment & newDevelomentFinished
# * hasStaging
# * country (la selección ya era España)
# * province (la selección era Madrid)
# * suggestedTexts
# * neighborhood
# * municipality
# * url
# * address, lat & long

# %%
df.drop(columns = ["externalReference", "suggestedTexts","thumbnail", "detailedType", "topNewDevelopment",
                   "newDevelopmentFinished",'latitude','longitude',"province",'url','address',"hasStaging", "country","neighborhood","municipality"
                  ], inplace = True)

# %%
df.columns
# Out:
# Index(['propertyCode', 'numPhotos', 'floor', 'price', 'propertyType',
#        'operation', 'size', 'exterior', 'rooms', 'bathrooms', 'district',
#        'showAddress', 'distance', 'hasVideo', 'status', 'newDevelopment',
#        'hasLift', 'priceByArea', 'hasPlan', 'has3DTour', 'has360',
#        'parkingSpace'],
#       dtype='object')

# %% [markdown]
# ### hasLift  column

# %% [markdown]
# #### plotting

# %%
#columna hasLift puede ser una variable importante para el valor de la vivienda 
plt.figure(figsize=(6,4))


ax = sns.countplot(x="hasLift", data=df, palette='pastel' )
ax.set_xticklabels(ax.get_xticklabels(),  rotation=40, ha="right",fontsize=10)
plt.tight_layout() 

# Chart and axes titles
ax.set_title('Viviendas a la venta sin/con ascensor',fontsize = 18, fontweight='bold' )
ax.set_xlabel('Ascensor', fontsize = 15)
ax.set_ylabel('Count', fontsize = 15)

# show count (+ annotate)
for rect in ax.patches:
    ax.text (rect.get_x() + rect.get_width()  / 2,rect.get_height()+ 0.75,rect.get_height(),horizontalalignment='center', fontsize = 11)

plt.show()

# %% [markdown]
# ### numPhotos columns

# %%
df.numPhotos.unique()
# Out:
# array([  2,  42,  10,  40,  33,  23,  38,   7,  36,  46,  45,  19,  21,
#          8,  48,  30,  34,  16,  11,  28,  14,  13,  27,  22,  15,   5,
#         20,  35,  25,  29,  18,  24,  26,  12,   6,   0,   1,  43,  49,
#         17,   4,  53,  41,  57,  31,  37,  54,  39,  32,   9,  60,  61,
#         52,   3,  51,  82,  69,  44,  50,  68,  55,  66,  77,  56,  80,
#         78,  64,  65,  47,  67,  58,  71,  62,  70,  59,  95,  85,  90,
#        123,  63,  75, 119,  86,  72,  74,  73], dtype=int64)

# %% [markdown]
# ### parking column

# %%
df['parkingSpace'].unique()
# Out:
# array([nan,
#        "{'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True}",
#        "{'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': False, 'parkingSpacePrice': 25000.0}",
#        "{'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': False, 'parkingSpacePrice': 30000.0}",
#        "{'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': False, 'parkingSpacePrice': 21000.0}",
#        "{'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': False, 'parkingSpacePrice': 25900.0}",
#        "{'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': False, 'parkingSpacePrice': 180.0}",
#        "{'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': False, 'parkingSpacePrice': 150.0}",
#        "{'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': False, 'parkingSpacePrice': 18000.0}",
#        "{'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': False, 'parkingSpacePrice': 15000.0}",
#        "{'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': False, 'parkingSpacePrice': 95000.0}",
#        "{'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': False, 'parkingSpacePrice': 50000.0}",
#        "{'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': False, 'parkingSpacePrice': 28000.0}",
#        "{'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': False, 'parkingSpacePrice': 130.0}",
#        "{'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': False, 'parkingSpacePrice': 45000.0}",
#        "{'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': False, 'parkingSpacePrice': 55000.0}",
#        "{'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': False, 'parkingSpacePrice': 70000.0}",
#        "{'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': False, 'parkingSpacePrice': 65000.0}",
#        "{'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': False, 'parkingSpacePrice': 10000.0}",
#        "{'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': False, 'parkingSpacePrice': 16000.0}",
#        "{'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': False, 'parkingSpacePrice': 40000.0}",
#        "{'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': False, 'parkingSpacePrice': 17000.0}",
#        "{'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': False, 'parkingSpacePrice': 14000.0}",
#        "{'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': False, 'parkingSpacePrice': 250.0}",
#        "{'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': False, 'parkingSpacePrice': 20000.0}",
#        "{'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': False, 'parkingSpacePrice': 27000.0}",
#        "{'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': False, 'parkingSpacePrice': 140.0}",
#        "{'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': False, 'parkingSpacePrice': 12000.0}",
#        "{'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': False, 'parkingSpacePrice': 60000.0}",
#        "{'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': False, 'parkingSpacePrice': 35000.0}",
#        "{'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': False, 'parkingSpacePrice': 100.0}",
#        "{'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': False, 'parkingSpacePrice': 24000.0}"],
#       dtype=object)

# %% [markdown]
# #### creating new columns: has_parking, parkingincluded, parking_price

# %%
### nuevas columnas si tiene parking, si está incluido y el precio
has_parking = []
parkingincluded = []
parking_price = []

for i in df['parkingSpace']:
    if str(i) != "nan":
        d = eval(i)
        print(d, type(d))
        
        has_parking.append(d["hasParkingSpace"])
        parkingincluded.append(d["isParkingSpaceIncludedInPrice"])
        parking_price.append(d.get("parkingSpacePrice",False))
        
    else:
        has_parking.append(False)
        parkingincluded.append(False)
        parking_price.append(False)
# Out:
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': False, 'parkingSpacePrice': 25000.0} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': False, 'parkingSpacePrice': 30000.0} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': False, 'parkingSpacePrice': 25000.0} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': False, 'parkingSpacePrice': 30000.0} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': False, 'parkingSpacePrice': 25000.0} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': False, 'parkingSpacePrice': 30000.0} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': False, 'parkingSpacePrice': 21000.0} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': False, 'parkingSpacePrice': 25900.0} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': False, 'parkingSpacePrice': 180.0} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': False, 'parkingSpacePrice': 30000.0} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': False, 'parkingSpacePrice': 150.0} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': False, 'parkingSpacePrice': 30000.0} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': False, 'parkingSpacePrice': 18000.0} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': False, 'parkingSpacePrice': 15000.0} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': False, 'parkingSpacePrice': 18000.0} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': False, 'parkingSpacePrice': 95000.0} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': False, 'parkingSpacePrice': 150.0} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': False, 'parkingSpacePrice': 95000.0} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': False, 'parkingSpacePrice': 50000.0} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': False, 'parkingSpacePrice': 50000.0} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': False, 'parkingSpacePrice': 28000.0} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': False, 'parkingSpacePrice': 130.0} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': False, 'parkingSpacePrice': 45000.0} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': False, 'parkingSpacePrice': 45000.0} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': False, 'parkingSpacePrice': 25000.0} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': False, 'parkingSpacePrice': 55000.0} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': False, 'parkingSpacePrice': 70000.0} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': False, 'parkingSpacePrice': 95000.0} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': False, 'parkingSpacePrice': 150.0} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': False, 'parkingSpacePrice': 65000.0} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': False, 'parkingSpacePrice': 30000.0} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': False, 'parkingSpacePrice': 10000.0} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': False, 'parkingSpacePrice': 180.0} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': False, 'parkingSpacePrice': 15000.0} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': False, 'parkingSpacePrice': 18000.0} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': False, 'parkingSpacePrice': 10000.0} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': False, 'parkingSpacePrice': 16000.0} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': False, 'parkingSpacePrice': 40000.0} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': False, 'parkingSpacePrice': 18000.0} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': False, 'parkingSpacePrice': 17000.0} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': False, 'parkingSpacePrice': 14000.0} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': False, 'parkingSpacePrice': 250.0} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': False, 'parkingSpacePrice': 40000.0} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': False, 'parkingSpacePrice': 16000.0} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': False, 'parkingSpacePrice': 70000.0} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': False, 'parkingSpacePrice': 25000.0} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': False, 'parkingSpacePrice': 18000.0} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': False, 'parkingSpacePrice': 25000.0} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': False, 'parkingSpacePrice': 20000.0} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': False, 'parkingSpacePrice': 10000.0} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': False, 'parkingSpacePrice': 40000.0} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': False, 'parkingSpacePrice': 40000.0} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': False, 'parkingSpacePrice': 40000.0} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': False, 'parkingSpacePrice': 40000.0} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': False, 'parkingSpacePrice': 27000.0} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': False, 'parkingSpacePrice': 30000.0} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': False, 'parkingSpacePrice': 20000.0} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': False, 'parkingSpacePrice': 18000.0} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': False, 'parkingSpacePrice': 15000.0} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': False, 'parkingSpacePrice': 25000.0} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': False, 'parkingSpacePrice': 15000.0} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': False, 'parkingSpacePrice': 140.0} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': False, 'parkingSpacePrice': 12000.0} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': False, 'parkingSpacePrice': 15000.0} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': False, 'parkingSpacePrice': 60000.0} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': False, 'parkingSpacePrice': 35000.0} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': False, 'parkingSpacePrice': 60000.0} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': False, 'parkingSpacePrice': 60000.0} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# ...
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': False, 'parkingSpacePrice': 18000.0} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': False, 'parkingSpacePrice': 100.0} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': False, 'parkingSpacePrice': 45000.0} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': False, 'parkingSpacePrice': 30000.0} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': False, 'parkingSpacePrice': 24000.0} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': False, 'parkingSpacePrice': 20000.0} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': False, 'parkingSpacePrice': 28000.0} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': False, 'parkingSpacePrice': 15000.0} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': False, 'parkingSpacePrice': 40000.0} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': False, 'parkingSpacePrice': 28000.0} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': False, 'parkingSpacePrice': 65000.0} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': False, 'parkingSpacePrice': 40000.0} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>
# {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True} <class 'dict'>

# %%
df["hasParkingSpace"] = has_parking
df["isParkingSpaceIncludedInPrice"] = parkingincluded
df["parkingSpacePrice"] = parking_price

# %%
df.head()
# Out:
#    propertyCode  numPhotos floor      price propertyType operation   size  \
# 0      94477419          2     1   114000.0         flat      sale   53.0
# 1      94477330         42     1   319000.0         flat      sale   97.0
# 2      94477212         10     2   496000.0         flat      sale  130.0
# 3      82312915         40     3  1340000.0         flat      sale  183.0
# 4      94476388          2    bj   290000.0         flat      sale   60.0
#
#    exterior  rooms  bathrooms  ... newDevelopment  hasLift  priceByArea  \
# 0     False      1          1  ...          False    False       2151.0
# 1      True      5          1  ...          False     True       3289.0
# 2     False      2          1  ...          False    False       3815.0
# 3      True      4          4  ...          False     True       7322.0
# 4     False      2          1  ...          False     True       4833.0
#
#    hasPlan has3DTour  has360  \
# 0    False     False   False
# 1    False     False   False
# 2    False     False   False
# 3    False     False   False
# 4     True     False   False
#
#                                         parkingSpace  hasParkingSpace  \
# 0                                                NaN            False
# 1                                                NaN            False
# 2                                                NaN            False
# 3  {'hasParkingSpace': True, 'isParkingSpaceInclu...             True
# 4                                                NaN            False
#
#    isParkingSpaceIncludedInPrice  parkingSpacePrice
# 0                          False              False
# 1                          False              False
# 2                          False              False
# 3                           True              False
# 4                          False              False
#
# [5 rows x 25 columns]

# %%
df.drop(["parkingSpace"],axis=1, inplace=True)

# %%
df.head()
# Out:
#    propertyCode  numPhotos floor      price propertyType operation   size  \
# 0      94477419          2     1   114000.0         flat      sale   53.0
# 1      94477330         42     1   319000.0         flat      sale   97.0
# 2      94477212         10     2   496000.0         flat      sale  130.0
# 3      82312915         40     3  1340000.0         flat      sale  183.0
# 4      94476388          2    bj   290000.0         flat      sale   60.0
#
#    exterior  rooms  bathrooms  ... status  newDevelopment  hasLift  \
# 0     False      1          1  ...   good           False    False
# 1      True      5          1  ...   good           False     True
# 2     False      2          1  ...   good           False    False
# 3      True      4          4  ...   good           False     True
# 4     False      2          1  ...   good           False     True
#
#    priceByArea hasPlan  has3DTour has360  hasParkingSpace  \
# 0       2151.0   False      False  False            False
# 1       3289.0   False      False  False            False
# 2       3815.0   False      False  False            False
# 3       7322.0   False      False  False             True
# 4       4833.0    True      False  False            False
#
#    isParkingSpaceIncludedInPrice  parkingSpacePrice
# 0                          False              False
# 1                          False              False
# 2                          False              False
# 3                           True              False
# 4                          False              False
#
# [5 rows x 24 columns]

# %% [markdown]
# ### floor column

# %%
df.floor.unique()
# Out:
# array(['1', '2', '3', 'bj', '4', '7', nan, '13', '14', 'ss', '5', '8',
#        '6', '10', 'en', '9', 'st', '11', '19', '12', '15', '20', '16'],
#       dtype=object)

# %%
df.floor=df.floor.replace(['bj','en'],0)
df.floor=df.floor.replace(['st','ss'], -1)

# %% [markdown]
# #### plotting

# %%
plt.figure(figsize=(12,6))


ax = sns.countplot(x="floor", data=df, palette='pastel' )
ax.set_xticklabels(ax.get_xticklabels(),  rotation=40, ha="right",fontsize=10)
plt.tight_layout() 

# Chart and axes titles
ax.set_title('Floor Number',fontsize = 18, fontweight='bold' )
ax.set_xlabel('floor', fontsize = 15)
ax.set_ylabel('Count', fontsize = 15)

# show count (+ annotate)
for rect in ax.patches:
    ax.text (rect.get_x() + rect.get_width()  / 2,rect.get_height()+ 0.75,rect.get_height(),horizontalalignment='center', fontsize = 11)

plt.show()

# %% [markdown]
# ### new column preciom2=price/size and dif_priceByArea_preciom2

# %%
df["preciom2"]=df["price"]/df['size']

# %% [markdown]
# #### comparing calculated preciom2 vs values dif_priceByArea_preciom2

# %%
df["dif_priceByArea_preciom2"]=df['priceByArea']-df['preciom2']
df["dif_priceByArea_preciom2"].mean()
#ambas columnas tienen un valor muy silimar, el el gráfico se superponen
# Out:
# -0.002399238152546356

# %%
df['priceByArea'] = df['priceByArea'].astype(int)
df['preciom2'] = df['preciom2'].astype(int)

# %%
df.columns
# Out:
# Index(['propertyCode', 'numPhotos', 'floor', 'price', 'propertyType',
#        'operation', 'size', 'exterior', 'rooms', 'bathrooms', 'district',
#        'showAddress', 'distance', 'hasVideo', 'status', 'newDevelopment',
#        'hasLift', 'priceByArea', 'hasPlan', 'has3DTour', 'has360',
#        'hasParkingSpace', 'isParkingSpaceIncludedInPrice', 'parkingSpacePrice',
#        'preciom2', 'dif_priceByArea_preciom2'],
#       dtype='object')

# %% [markdown]
# #### plotting both distibutions on the same figure

# %%
fig = sns.kdeplot(df['priceByArea'], shade=True, color="r")
fig = sns.kdeplot(df['preciom2'], shade=True, color="b")
plt.show()

# %%
import numpy as np
import scipy.stats
import numpy as np
from numpy import linspace
from scipy.stats import gaussian_kde
# Fig size

# %% [markdown]
# #### plotting density chart for Precio medio m2

# %%
plt.rcParams["figure.figsize"]=12,8

kde = gaussian_kde(df.preciom2)
x_range = linspace(min(df.preciom2), max(df.preciom2), len(df.preciom2))

# multiply by -1 to reverse axis (mirror plot)
sns.lineplot(x=x_range*1, y=kde(x_range) * 1, color='orange') 
plt.fill_between(x_range*1, kde(x_range) * 1, color='orange')

# add axis names        
plt.xlabel("Precio medio m2")
plt.axhline(y=0, linestyle='-',linewidth=1, color='black')



# show the graph
plt.show()

# %%
#eliminaremos esta columna de cálculo porque es redundante con la de idealista
#df.drop(['preciom2'],axis=1, inplace=True)

# %% [markdown]
# ### excel dataframe with district names for later merge

# %%
df.district.to_excel("../output/tabla_district.xls")

# %%
df.district.unique()
# Out:
# array(['Arganzuela', 'Latina', 'Centro', 'Chamartín', 'Chamberí',
#        'Moratalaz', 'Tetuán', 'Carabanchel', 'Retiro', 'Vicálvaro',
#        'Fuencarral', 'San Blas', 'Puente de Vallecas',
#        'Barrio de Salamanca', 'Ciudad Lineal', 'Moncloa', 'Villaverde',
#        'Hortaleza', 'Villa de Vallecas', 'Usera'], dtype=object)

# %% [markdown]
# ### Importing df población distrito for later merging:

# %%
district_population=pd.read_excel("../output/poblacion_distrito.xls")
district_population.columns
# Out:
# Index(['Unnamed: 0', 'district', 'population'], dtype='object')

# %%
district_population.drop(columns = [district_population.columns[0]], inplace = True)
district_population.head()
# Out:
#              district  population
# 0         Carabanchel     253.797
# 1          Fuencarral     246.640
# 2              Latina     238.901
# 3  Puente de Vallecas     235.418
# 4       Ciudad Lineal     216.861

# %% [markdown]
# #### merge to idealista df

# %%
df=pd.merge(df, district_population,on="district")

# %%
df.head()
# Out:
#    propertyCode  numPhotos floor     price propertyType operation   size  \
# 0      94477419          2     1  114000.0         flat      sale   53.0
# 1      94474758          7     1  149000.0         flat      sale   38.0
# 2      94477419          2     1  114000.0         flat      sale   53.0
# 3      94474758          7     1  149000.0         flat      sale   38.0
# 4      94471119         49     1  500000.0         flat      sale  125.0
#
#    exterior  rooms  bathrooms  ... priceByArea  hasPlan  has3DTour  has360  \
# 0     False      1          1  ...        2151    False      False   False
# 1     False      1          1  ...        3921    False      False   False
# 2     False      1          1  ...        2151    False      False   False
# 3     False      1          1  ...        3921    False      False   False
# 4      True      3          2  ...        4000     True      False   False
#
#   hasParkingSpace  isParkingSpaceIncludedInPrice parkingSpacePrice  preciom2  \
# 0           False                          False             False      2150
# 1           False                          False             False      3921
# 2           False                          False             False      2150
# 3           False                          False             False      3921
# 4            True                           True             False      4000
#
#    dif_priceByArea_preciom2  population
# 0                  0.056604     154.264
# 1                 -0.052632     154.264
# 2                  0.056604     154.264
# 3                 -0.052632     154.264
# 4                  0.000000     154.264
#
# [5 rows x 27 columns]

# %%
len(df)
# Out:
# 3672

# %%
df.population.unique()
# Out:
# array([154.264, 238.901, 135.314, 146.231, 139.914,  94.818, 158.494,
#        253.797, 119.687,  72.294, 246.64 , 158.602, 235.418, 146.578,
#        216.861, 119.789, 149.277, 188.694, 110.643, 139.909])

# %%
df.district.unique()
# Out:
# array(['Arganzuela', 'Latina', 'Centro', 'Chamartín', 'Chamberí',
#        'Moratalaz', 'Tetuán', 'Carabanchel', 'Retiro', 'Vicálvaro',
#        'Fuencarral', 'San Blas', 'Puente de Vallecas',
#        'Barrio de Salamanca', 'Ciudad Lineal', 'Moncloa', 'Villaverde',
#        'Hortaleza', 'Villa de Vallecas', 'Usera'], dtype=object)

# %% [markdown]
# ### Importing df criminalidad distrito for later merging:

# %%
district_insecurity=pd.read_excel("../output/criminalidad_distrito.xls")
district_insecurity.columns
# Out:
# Index(['Unnamed: 0', 'district', 'insecurity_ratio'], dtype='object')

# %%
district_insecurity.drop(columns = ['Unnamed: 0'], inplace = True)
district_insecurity.head()
# Out:
#       district  insecurity_ratio
# 0   Arganzuela             27.75
# 1      Barajas             33.50
# 2  Carabanchel             90.75
# 3       Centro            200.75
# 4    Chamartín             34.00

# %% [markdown]
# #### merge to idealista df

# %%
df=pd.merge(df, district_insecurity,on="district")

# %%
len(df)
# Out:
# 3672

# %%
df.district.unique()
# Out:
# array(['Arganzuela', 'Latina', 'Centro', 'Chamartín', 'Chamberí',
#        'Moratalaz', 'Tetuán', 'Carabanchel', 'Retiro', 'Vicálvaro',
#        'Fuencarral', 'San Blas', 'Puente de Vallecas',
#        'Barrio de Salamanca', 'Ciudad Lineal', 'Moncloa', 'Villaverde',
#        'Hortaleza', 'Villa de Vallecas', 'Usera'], dtype=object)

# %%
df.head()
# Out:
#    propertyCode  numPhotos floor     price propertyType operation   size  \
# 0      94477419          2     1  114000.0         flat      sale   53.0
# 1      94474758          7     1  149000.0         flat      sale   38.0
# 2      94477419          2     1  114000.0         flat      sale   53.0
# 3      94474758          7     1  149000.0         flat      sale   38.0
# 4      94471119         49     1  500000.0         flat      sale  125.0
#
#    exterior  rooms  bathrooms  ... hasPlan  has3DTour  has360  \
# 0     False      1          1  ...   False      False   False
# 1     False      1          1  ...   False      False   False
# 2     False      1          1  ...   False      False   False
# 3     False      1          1  ...   False      False   False
# 4      True      3          2  ...    True      False   False
#
#    hasParkingSpace isParkingSpaceIncludedInPrice  parkingSpacePrice preciom2  \
# 0            False                         False              False     2150
# 1            False                         False              False     3921
# 2            False                         False              False     2150
# 3            False                         False              False     3921
# 4             True                          True              False     4000
#
#    dif_priceByArea_preciom2  population  insecurity_ratio
# 0                  0.056604     154.264             27.75
# 1                 -0.052632     154.264             27.75
# 2                  0.056604     154.264             27.75
# 3                 -0.052632     154.264             27.75
# 4                  0.000000     154.264             27.75
#
# [5 rows x 28 columns]

# %% [markdown]
# ### New column criminality ratio/population/district

# %%
df['criminality_ratio']=df.insecurity_ratio/df.population

# %% [markdown]
# #### drop previous column

# %%
df.drop(columns = ["insecurity_ratio",], inplace = True)

# %%
df.district.unique()
# Out:
# array(['Arganzuela', 'Latina', 'Centro', 'Chamartín', 'Chamberí',
#        'Moratalaz', 'Tetuán', 'Carabanchel', 'Retiro', 'Vicálvaro',
#        'Fuencarral', 'San Blas', 'Puente de Vallecas',
#        'Barrio de Salamanca', 'Ciudad Lineal', 'Moncloa', 'Villaverde',
#        'Hortaleza', 'Villa de Vallecas', 'Usera'], dtype=object)

# %%
df.head()
# Out:
#    propertyCode  numPhotos floor     price propertyType operation   size  \
# 0      94477419          2     1  114000.0         flat      sale   53.0
# 1      94474758          7     1  149000.0         flat      sale   38.0
# 2      94477419          2     1  114000.0         flat      sale   53.0
# 3      94474758          7     1  149000.0         flat      sale   38.0
# 4      94471119         49     1  500000.0         flat      sale  125.0
#
#    exterior  rooms  bathrooms  ... hasPlan  has3DTour  has360  \
# 0     False      1          1  ...   False      False   False
# 1     False      1          1  ...   False      False   False
# 2     False      1          1  ...   False      False   False
# 3     False      1          1  ...   False      False   False
# 4      True      3          2  ...    True      False   False
#
#    hasParkingSpace isParkingSpaceIncludedInPrice  parkingSpacePrice preciom2  \
# 0            False                         False              False     2150
# 1            False                         False              False     3921
# 2            False                         False              False     2150
# 3            False                         False              False     3921
# 4             True                          True              False     4000
#
#    dif_priceByArea_preciom2  population  criminality_ratio
# 0                  0.056604     154.264           0.179886
# 1                 -0.052632     154.264           0.179886
# 2                  0.056604     154.264           0.179886
# 3                 -0.052632     154.264           0.179886
# 4                  0.000000     154.264           0.179886
#
# [5 rows x 28 columns]

# %% [markdown]
# ### munimadrid  av. price for later comparation

# %%
munimadrid_precio_medio_vivienda=pd.read_excel("../output/precio_medio_munimadrid.xls")
munimadrid_precio_medio_vivienda.head()
# Out:
#          Distrito  mean_price_munimadrid             district
# 0      01. Centro              5254.3125               Centro
# 1  02. Arganzuela              4170.1250           Arganzuela
# 2      03. Retiro              4837.0000               Retiro
# 3   04. Salamanca              6224.1250  Barrio de Salamanca
# 4   05. Chamartín              5403.5625            Chamartín

# %%
munimadrid_precio_medio_vivienda.drop(munimadrid_precio_medio_vivienda.columns[0],axis=1, inplace=True)

# %%
munimadrid_precio_medio_vivienda.head(2)
# Out:
#    mean_price_munimadrid    district
# 0              5254.3125      Centro
# 1              4170.1250  Arganzuela

# %% [markdown]
# #### merge to idealista df

# %%
df=pd.merge(df,munimadrid_precio_medio_vivienda,on="district")
df
# Out:
#       propertyCode  numPhotos floor     price propertyType operation   size  \
# 0         94477419          2     1  114000.0         flat      sale   53.0
# 1         94474758          7     1  149000.0         flat      sale   38.0
# 2         94477419          2     1  114000.0         flat      sale   53.0
# 3         94474758          7     1  149000.0         flat      sale   38.0
# 4         94471119         49     1  500000.0         flat      sale  125.0
# ...            ...        ...   ...       ...          ...       ...    ...
# 3667      94304495         25     2  159000.0         flat      sale  123.0
# 3668      94304043          8     2  199000.0       duplex      sale  133.0
# 3669      94303103         25     2  139500.0         flat      sale   99.0
# 3670      94301925         27     0  119000.0         flat      sale   71.0
# 3671      94300959         10     7  118000.0         flat      sale   78.0
#
#       exterior  rooms  bathrooms  ... has3DTour  has360  hasParkingSpace  \
# 0        False      1          1  ...     False   False            False
# 1        False      1          1  ...     False   False            False
# 2        False      1          1  ...     False   False            False
# 3        False      1          1  ...     False   False            False
# 4         True      3          2  ...     False   False             True
# ...        ...    ...        ...  ...       ...     ...              ...
# 3667      True      2          2  ...     False    True             True
# 3668     False      4          2  ...     False   False            False
# 3669      True      3          2  ...     False   False            False
# 3670     False      3          1  ...     False   False            False
# 3671      True      2          1  ...     False   False            False
#
#       isParkingSpaceIncludedInPrice parkingSpacePrice  preciom2  \
# 0                             False             False      2150
# 1                             False             False      3921
# 2                             False             False      2150
# 3                             False             False      3921
# 4                              True             False      4000
# ...                             ...               ...       ...
# 3667                           True             False      1292
# 3668                          False             False      1496
# 3669                          False             False      1409
# 3670                          False             False      1676
# 3671                          False             False      1512
#
#      dif_priceByArea_preciom2  population  criminality_ratio  \
# 0                    0.056604     154.264           0.179886
# 1                   -0.052632     154.264           0.179886
# 2                    0.056604     154.264           0.179886
# 3                   -0.052632     154.264           0.179886
# 4                    0.000000     154.264           0.179886
# ...                       ...         ...                ...
# 3667                 0.317073     139.909           0.400260
# 3668                -0.240602     139.909           0.400260
# 3669                -0.090909     139.909           0.400260
# 3670                -0.056338     139.909           0.400260
# 3671                 0.179487     139.909           0.400260
#
#       mean_price_munimadrid
# 0                 4170.1250
# 1                 4170.1250
# 2                 4170.1250
# 3                 4170.1250
# 4                 4170.1250
# ...                     ...
# 3667              2104.0625
# 3668              2104.0625
# 3669              2104.0625
# 3670              2104.0625
# 3671              2104.0625
#
# [3672 rows x 29 columns]

# %%
df.district.unique()
# Out:
# array(['Arganzuela', 'Latina', 'Centro', 'Chamartín', 'Chamberí',
#        'Moratalaz', 'Tetuán', 'Carabanchel', 'Retiro', 'Vicálvaro',
#        'Fuencarral', 'San Blas', 'Puente de Vallecas',
#        'Barrio de Salamanca', 'Ciudad Lineal', 'Moncloa', 'Villaverde',
#        'Hortaleza', 'Villa de Vallecas', 'Usera'], dtype=object)

# %%
len(df)
# Out:
# 3672

# %%
df_precios_medios=df[["district","preciom2","mean_price_munimadrid"]]
df_precios_medios.preciom2=pd.to_numeric(df_precios_medios.preciom2)
# Out:
# C:\Users\pinil\anaconda3\lib\site-packages\pandas\core\generic.py:5303: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value

# %% [markdown]
# #### comparing av. prices in idealista vs. munimadrid

# %%
df2=df_precios_medios.groupby("district")['preciom2',"mean_price_munimadrid"].mean()
df2
#similar calculations
# Out:
# <ipython-input-86-62e00b42eba9>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df2=df_precios_medios.groupby("district")['preciom2',"mean_price_munimadrid"].mean()
#                         preciom2  mean_price_munimadrid
# district
# Arganzuela           4020.835366              4170.1250
# Barrio de Salamanca  6332.976623              6224.1250
# Carabanchel          2212.472393              2289.8750
# Centro               4938.497585              5254.3125
# Chamartín            5180.656051              5403.5625
# Chamberí             5418.404762              5657.3125
# Ciudad Lineal        3150.331950              3149.0000
# Fuencarral           3485.565517              3736.8750
# Hortaleza            3597.079365              3913.1250
# Latina               2374.639053              2422.8750
# Moncloa              4330.696970              4178.1250
# Moratalaz            2515.765957              2662.6875
# Puente de Vallecas   2109.951542              2028.6250
# Retiro               5200.809917              4837.0000
# San Blas             2632.781690              2675.6875
# Tetuán               3755.676349              3899.9375
# Usera                2047.360000              2104.0625
# Vicálvaro            2321.468085              2497.3750
# Villa de Vallecas    2392.822581              2531.5000
# Villaverde           1694.931034              1822.3750

# %%
df2.columns
# Out:
# Index(['preciom2', 'mean_price_munimadrid'], dtype='object')

# %% [markdown]
# ### plotting both distibutions, look the same

# %%
fig = sns.kdeplot(df2['preciom2'], shade=True, color="r")
fig = sns.kdeplot(df2['mean_price_munimadrid'], shade=True, color="b")
plt.show()

# %% [markdown]
# ### importing centros educativos por distrito

# %%
centros_educativos=pd.read_excel("../input/centros_educativos_final.xls")

# %%
centros_educativos.head(3)
# Out:
#    Unnamed: 0                                                @id  \
# 0           0  https://datos.madrid.es/egob/catalogo/tipo/ent...
# 1           1  https://datos.madrid.es/egob/catalogo/tipo/ent...
# 2           2  https://datos.madrid.es/egob/catalogo/tipo/ent...
#
#                                                @type        id  \
# 0  https://datos.madrid.es/egob/kos/entidadesYorg...    167390
# 1  https://datos.madrid.es/egob/kos/entidadesYorg...      5373
# 2  https://datos.madrid.es/egob/kos/entidadesYorg...  10127337
#
#                                                title  \
# 0                             Academia Darío Estudio
# 1                      Altair, Colegio Internacional
# 2  Aula Municipal de Formación de Personas Adulta...
#
#                                             relation  \
# 0  http://www.madrid.es/sites/v/index.jsp?vgnextc...
# 1  http://www.madrid.es/sites/v/index.jsp?vgnextc...
# 2  http://www.madrid.es/sites/v/index.jsp?vgnextc...
#
#                                 address.district.@id  \
# 0  https://datos.madrid.es/egob/kos/Provincia/Mad...
# 1  https://datos.madrid.es/egob/kos/Provincia/Mad...
# 2  https://datos.madrid.es/egob/kos/Provincia/Mad...
#
#                                     address.area.@id address.locality  \
# 0  https://datos.madrid.es/egob/kos/Provincia/Mad...           MADRID
# 1  https://datos.madrid.es/egob/kos/Provincia/Mad...           MADRID
# 2  https://datos.madrid.es/egob/kos/Provincia/Mad...           MADRID
#
#    address.postal-code address.street-address  location.latitude  \
# 0                28013      CALLE GRAN VIA 63          40.422491
# 1                28036    CALLE JOAQUIN BAU 4          40.463788
# 2                28005         CALLE CASINO 5          40.406617
#
#    location.longitude                     organization.organization-desc  \
# 0           -3.709818   ENSEÑANZA: BACHILLERATO (Humanidades  y C. So...
# 1           -3.685848   ENSEÑANZA: Educación infantil - Primaria - ES...
# 2           -3.705326   Programas Formativos:   Español para extranje...
#
#    organization.accesibility  \
# 0                        0.0
# 1                        0.0
# 2                        1.0
#
#                                organization.schedule  \
# 0                                                NaN
# 1                                                NaN
# 2  De lunes a jueves:    Mañanas de 08:30 a 13:00...
#
#                      organization.services  \
# 0                                      NaN
# 1  Comedor - Transporte - Horario ampliado
# 2                                      NaN
#
#                       organization.organization-name
# 0                             Academia Darío Estudio
# 1                      Altair, Colegio Internacional
# 2  Aula Municipal de Formación de Personas Adulta...

# %%
#getting district
centros_educativos['address.district.@id']=centros_educativos['address.district.@id'].apply(lambda x: (x[76:]))
print(centros_educativos['address.district.@id'])
# Out:
# 0                   Centro
# 1                Chamartin
# 2                   Centro
# 3                 Chamberi
# 4             CiudadLineal
#                ...
# 1450             Salamanca
# 1451                Centro
# 1452             Salamanca
# 1453             Salamanca
# 1454    SanBlas-Canillejas
# Name: address.district.@id, Length: 1455, dtype: object

# %% [markdown]
# #### new dataframe only with required columns

# %%
df3=centros_educativos[["address.district.@id", "title"]]
df3
# Out:
#      address.district.@id                                              title
# 0                  Centro                             Academia Darío Estudio
# 1               Chamartin                      Altair, Colegio Internacional
# 2                  Centro  Aula Municipal de Formación de Personas Adulta...
# 3                Chamberi  Aula Municipal de Formación de Personas Adulta...
# 4            CiudadLineal  Aula Municipal de Formación de Personas Adulta...
# ...                   ...                                                ...
# 1450            Salamanca          Organización Profesional Española (OPESA)
# 1451               Centro            Real Colegio Santa Isabel - La Asunción
# 1452            Salamanca           San Román Escuela de Estudios Superiores
# 1453            Salamanca  Sanromán Centro Internacional de Estudios Prof...
# 1454   SanBlas-Canillejas                      Trainek formación profesional
#
# [1455 rows x 2 columns]

# %%
df3 = df3.groupby('address.district.@id').count()
df3
# Out:
#                       title
# address.district.@id
# Arganzuela               57
# Barajas                  27
# Carabanchel              93
# Centro                   52
# Chamartin                98
# Chamberi                 62
# CiudadLineal            102
# Distrito                  1
# Fuencarral-ElPardo      127
# Hortaleza               103
# Latina                   92
# Moncloa-Aravaca          87
# Moratalaz                43
# PuenteDeVallecas         97
# Retiro                   47
# Salamanca                39
# SanBlas-Canillejas       77
# Tetuan                   44
# Usera                    58
# Vicalvaro                32
# VillaDeVallecas          49
# Villaverde               68

# %%
df3['address.district.@id'] = df3.index
df3
# Out:
#                       title address.district.@id
# address.district.@id
# Arganzuela               57           Arganzuela
# Barajas                  27              Barajas
# Carabanchel              93          Carabanchel
# Centro                   52               Centro
# Chamartin                98            Chamartin
# Chamberi                 62             Chamberi
# CiudadLineal            102         CiudadLineal
# Distrito                  1             Distrito
# Fuencarral-ElPardo      127   Fuencarral-ElPardo
# Hortaleza               103            Hortaleza
# Latina                   92               Latina
# Moncloa-Aravaca          87      Moncloa-Aravaca
# Moratalaz                43            Moratalaz
# PuenteDeVallecas         97     PuenteDeVallecas
# Retiro                   47               Retiro
# Salamanca                39            Salamanca
# SanBlas-Canillejas       77   SanBlas-Canillejas
# Tetuan                   44               Tetuan
# Usera                    58                Usera
# Vicalvaro                32            Vicalvaro
# VillaDeVallecas          49      VillaDeVallecas
# Villaverde               68           Villaverde

# %%
#df3.drop(["Distrito"],axis=0, inplace=True)

# %%
df3=df3.rename(columns={"address.district.@id":"district", "title":"centro_educativo"})

# %% [markdown]
# #### preparing df3 for merge

# %%
df3.district
# Out:
# address.district.@id
# Arganzuela                    Arganzuela
# Barajas                          Barajas
# Carabanchel                  Carabanchel
# Centro                            Centro
# Chamartin                      Chamartin
# Chamberi                        Chamberi
# CiudadLineal                CiudadLineal
# Distrito                        Distrito
# Fuencarral-ElPardo    Fuencarral-ElPardo
# Hortaleza                      Hortaleza
# Latina                            Latina
# Moncloa-Aravaca          Moncloa-Aravaca
# Moratalaz                      Moratalaz
# PuenteDeVallecas        PuenteDeVallecas
# Retiro                            Retiro
# Salamanca                      Salamanca
# SanBlas-Canillejas    SanBlas-Canillejas
# Tetuan                            Tetuan
# Usera                              Usera
# Vicalvaro                      Vicalvaro
# VillaDeVallecas          VillaDeVallecas
# Villaverde                    Villaverde
# Name: district, dtype: object

# %%
sorted(df.district.unique())
# Out:
# ['Arganzuela',
#  'Barrio de Salamanca',
#  'Carabanchel',
#  'Centro',
#  'Chamartín',
#  'Chamberí',
#  'Ciudad Lineal',
#  'Fuencarral',
#  'Hortaleza',
#  'Latina',
#  'Moncloa',
#  'Moratalaz',
#  'Puente de Vallecas',
#  'Retiro',
#  'San Blas',
#  'Tetuán',
#  'Usera',
#  'Vicálvaro',
#  'Villa de Vallecas',
#  'Villaverde']

# %%
df3.replace({"Salamanca": "Barrio de Salamanca", "Chamartin": "Chamartín","Chamberi":"Chamberí",
            "CiudadLineal":"Ciudad Lineal","Fuencarral-ElPardo":"Fuencarral",'Moncloa-Aravaca':'Moncloa',
            'PuenteDeVallecas':"Puente de Vallecas",'SanBlas-Canillejas':"San Blas", "Tetuan":"Tetuán",
            "Vicalvaro":"Vicálvaro",  'VillaDeVallecas': 'Villad de Vallecas'}, inplace=True)

# %%
df3.rename_axis("axis")
# Out:
#                     centro_educativo             district
# axis
# Arganzuela                        57           Arganzuela
# Barajas                           27              Barajas
# Carabanchel                       93          Carabanchel
# Centro                            52               Centro
# Chamartin                         98            Chamartín
# Chamberi                          62             Chamberí
# CiudadLineal                     102        Ciudad Lineal
# Distrito                           1             Distrito
# Fuencarral-ElPardo               127           Fuencarral
# Hortaleza                        103            Hortaleza
# Latina                            92               Latina
# Moncloa-Aravaca                   87              Moncloa
# Moratalaz                         43            Moratalaz
# PuenteDeVallecas                  97   Puente de Vallecas
# Retiro                            47               Retiro
# Salamanca                         39  Barrio de Salamanca
# SanBlas-Canillejas                77             San Blas
# Tetuan                            44               Tetuán
# Usera                             58                Usera
# Vicalvaro                         32            Vicálvaro
# VillaDeVallecas                   49   Villad de Vallecas
# Villaverde                        68           Villaverde

# %%
df3.columns
# Out:
# Index(['centro_educativo', 'district'], dtype='object')

# %%
#delete row Distrito
df3.drop(["Distrito"],axis=0, inplace=True)

# %%
#plotting centros educativos ratio by district
df3.plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='address.district.@id'>

# %%
len(df)
# Out:
# 3672

# %%
#merge to idealista df
df=pd.merge(df, df3, on="district")

# %%
df.columns
# Out:
# Index(['propertyCode', 'numPhotos', 'floor', 'price', 'propertyType',
#        'operation', 'size', 'exterior', 'rooms', 'bathrooms', 'district',
#        'showAddress', 'distance', 'hasVideo', 'status', 'newDevelopment',
#        'hasLift', 'priceByArea', 'hasPlan', 'has3DTour', 'has360',
#        'hasParkingSpace', 'isParkingSpaceIncludedInPrice', 'parkingSpacePrice',
#        'preciom2', 'dif_priceByArea_preciom2', 'population',
#        'criminality_ratio', 'mean_price_munimadrid', 'centro_educativo'],
#       dtype='object')

# %%
len(df)
# Out:
# 3610

# %%
#New column ratio centros educativos/population/district
df['education_centers_ratio']=df.centro_educativo/df.population

#drop column centro education
df.drop(columns = ["centro_educativo",], inplace = True)

# %%
df.head(3)
# Out:
#    propertyCode  numPhotos floor     price propertyType operation  size  \
# 0      94477419          2     1  114000.0         flat      sale  53.0
# 1      94474758          7     1  149000.0         flat      sale  38.0
# 2      94477419          2     1  114000.0         flat      sale  53.0
#
#    exterior  rooms  bathrooms  ... has360  hasParkingSpace  \
# 0     False      1          1  ...  False            False
# 1     False      1          1  ...  False            False
# 2     False      1          1  ...  False            False
#
#    isParkingSpaceIncludedInPrice  parkingSpacePrice preciom2  \
# 0                          False              False     2150
# 1                          False              False     3921
# 2                          False              False     2150
#
#    dif_priceByArea_preciom2 population  criminality_ratio  \
# 0                  0.056604    154.264           0.179886
# 1                 -0.052632    154.264           0.179886
# 2                  0.056604    154.264           0.179886
#
#    mean_price_munimadrid  education_centers_ratio
# 0               4170.125                 0.369496
# 1               4170.125                 0.369496
# 2               4170.125                 0.369496
#
# [3 rows x 30 columns]

# %% [markdown]
# ### tratar los últimos valores 0/nan

# %%
#True=1; suma los 1
null_cols = df.isnull().sum()
null_cols
# Out:
# propertyCode                       0
# numPhotos                          0
# floor                            238
# price                              0
# propertyType                       0
# operation                          0
# size                               0
# exterior                           0
# rooms                              0
# bathrooms                          0
# district                           0
# showAddress                        0
# distance                           0
# hasVideo                           0
# status                             0
# newDevelopment                     0
# hasLift                          185
# priceByArea                        0
# hasPlan                            0
# has3DTour                          0
# has360                             0
# hasParkingSpace                    0
# isParkingSpaceIncludedInPrice      0
# parkingSpacePrice                  0
# preciom2                           0
# dif_priceByArea_preciom2           0
# population                         0
# criminality_ratio                  0
# mean_price_munimadrid              0
# education_centers_ratio            0
# dtype: int64

# %%
df
# Out:
#       propertyCode  numPhotos floor     price propertyType operation   size  \
# 0         94477419          2     1  114000.0         flat      sale   53.0
# 1         94474758          7     1  149000.0         flat      sale   38.0
# 2         94477419          2     1  114000.0         flat      sale   53.0
# 3         94474758          7     1  149000.0         flat      sale   38.0
# 4         94471119         49     1  500000.0         flat      sale  125.0
# ...            ...        ...   ...       ...          ...       ...    ...
# 3605      94304495         25     2  159000.0         flat      sale  123.0
# 3606      94304043          8     2  199000.0       duplex      sale  133.0
# 3607      94303103         25     2  139500.0         flat      sale   99.0
# 3608      94301925         27     0  119000.0         flat      sale   71.0
# 3609      94300959         10     7  118000.0         flat      sale   78.0
#
#       exterior  rooms  bathrooms  ... has360  hasParkingSpace  \
# 0        False      1          1  ...  False            False
# 1        False      1          1  ...  False            False
# 2        False      1          1  ...  False            False
# 3        False      1          1  ...  False            False
# 4         True      3          2  ...  False             True
# ...        ...    ...        ...  ...    ...              ...
# 3605      True      2          2  ...   True             True
# 3606     False      4          2  ...  False            False
# 3607      True      3          2  ...  False            False
# 3608     False      3          1  ...  False            False
# 3609      True      2          1  ...  False            False
#
#       isParkingSpaceIncludedInPrice  parkingSpacePrice preciom2  \
# 0                             False              False     2150
# 1                             False              False     3921
# 2                             False              False     2150
# 3                             False              False     3921
# 4                              True              False     4000
# ...                             ...                ...      ...
# 3605                           True              False     1292
# 3606                          False              False     1496
# 3607                          False              False     1409
# 3608                          False              False     1676
# 3609                          False              False     1512
#
#       dif_priceByArea_preciom2 population  criminality_ratio  \
# 0                     0.056604    154.264           0.179886
# 1                    -0.052632    154.264           0.179886
# 2                     0.056604    154.264           0.179886
# 3                    -0.052632    154.264           0.179886
# 4                     0.000000    154.264           0.179886
# ...                        ...        ...                ...
# 3605                  0.317073    139.909           0.400260
# 3606                 -0.240602    139.909           0.400260
# 3607                 -0.090909    139.909           0.400260
# 3608                 -0.056338    139.909           0.400260
# 3609                  0.179487    139.909           0.400260
#
#       mean_price_munimadrid  education_centers_ratio
# 0                 4170.1250                 0.369496
# 1                 4170.1250                 0.369496
# 2                 4170.1250                 0.369496
# 3                 4170.1250                 0.369496
# 4                 4170.1250                 0.369496
# ...                     ...                      ...
# 3605              2104.0625                 0.414555
# 3606              2104.0625                 0.414555
# 3607              2104.0625                 0.414555
# 3608              2104.0625                 0.414555
# 3609              2104.0625                 0.414555
#
# [3610 rows x 30 columns]

# %%
# fillna method with floor & hasLift with the mean, but it only works with hasLift
df.fillna(df[['floor','hasLift']].mean(),inplace=True)

# %%
null_cols = df.isnull().sum()
null_cols
# Out:
# propertyCode                       0
# numPhotos                          0
# floor                            238
# price                              0
# propertyType                       0
# operation                          0
# size                               0
# exterior                           0
# rooms                              0
# bathrooms                          0
# district                           0
# showAddress                        0
# distance                           0
# hasVideo                           0
# status                             0
# newDevelopment                     0
# hasLift                            0
# priceByArea                        0
# hasPlan                            0
# has3DTour                          0
# has360                             0
# hasParkingSpace                    0
# isParkingSpaceIncludedInPrice      0
# parkingSpacePrice                  0
# preciom2                           0
# dif_priceByArea_preciom2           0
# population                         0
# criminality_ratio                  0
# mean_price_munimadrid              0
# education_centers_ratio            0
# dtype: int64

# %%
#we drop las na
df = df.dropna()
df = df.reset_index(drop=True)

# %%
#True=1; suma los 1
null_cols = df.isnull().sum()
null_cols
# Out:
# propertyCode                     0
# numPhotos                        0
# floor                            0
# price                            0
# propertyType                     0
# operation                        0
# size                             0
# exterior                         0
# rooms                            0
# bathrooms                        0
# district                         0
# showAddress                      0
# distance                         0
# hasVideo                         0
# status                           0
# newDevelopment                   0
# hasLift                          0
# priceByArea                      0
# hasPlan                          0
# has3DTour                        0
# has360                           0
# hasParkingSpace                  0
# isParkingSpaceIncludedInPrice    0
# parkingSpacePrice                0
# preciom2                         0
# dif_priceByArea_preciom2         0
# population                       0
# criminality_ratio                0
# mean_price_munimadrid            0
# education_centers_ratio          0
# dtype: int64

# %%
len(df)
# Out:
# 3372

# %% [markdown]
# ### Dropping las unnecesary columns

# %%
df.columns
# Out:
# Index(['propertyCode', 'numPhotos', 'floor', 'price', 'propertyType',
#        'operation', 'size', 'exterior', 'rooms', 'bathrooms', 'district',
#        'showAddress', 'distance', 'hasVideo', 'status', 'newDevelopment',
#        'hasLift', 'priceByArea', 'hasPlan', 'has3DTour', 'has360',
#        'hasParkingSpace', 'isParkingSpaceIncludedInPrice', 'parkingSpacePrice',
#        'preciom2', 'dif_priceByArea_preciom2', 'population',
#        'criminality_ratio', 'mean_price_munimadrid',
#        'education_centers_ratio'],
#       dtype='object')

# %%
df.drop(columns = ['dif_priceByArea_preciom2', 'population','operation'], inplace = True)

# %%
df
# Out:
#       propertyCode  numPhotos floor     price propertyType   size  exterior  \
# 0         94477419          2     1  114000.0         flat   53.0     False
# 1         94474758          7     1  149000.0         flat   38.0     False
# 2         94477419          2     1  114000.0         flat   53.0     False
# 3         94474758          7     1  149000.0         flat   38.0     False
# 4         94471119         49     1  500000.0         flat  125.0      True
# ...            ...        ...   ...       ...          ...    ...       ...
# 3367      94304495         25     2  159000.0         flat  123.0      True
# 3368      94304043          8     2  199000.0       duplex  133.0     False
# 3369      94303103         25     2  139500.0         flat   99.0      True
# 3370      94301925         27     0  119000.0         flat   71.0     False
# 3371      94300959         10     7  118000.0         flat   78.0      True
#
#       rooms  bathrooms    district  ...  hasPlan  has3DTour  has360  \
# 0         1          1  Arganzuela  ...    False      False   False
# 1         1          1  Arganzuela  ...    False      False   False
# 2         1          1  Arganzuela  ...    False      False   False
# 3         1          1  Arganzuela  ...    False      False   False
# 4         3          2  Arganzuela  ...     True      False   False
# ...     ...        ...         ...  ...      ...        ...     ...
# 3367      2          2       Usera  ...    False      False    True
# 3368      4          2       Usera  ...    False      False   False
# 3369      3          2       Usera  ...    False      False   False
# 3370      3          1       Usera  ...    False      False   False
# 3371      2          1       Usera  ...    False      False   False
#
#      hasParkingSpace  isParkingSpaceIncludedInPrice parkingSpacePrice  \
# 0              False                          False             False
# 1              False                          False             False
# 2              False                          False             False
# 3              False                          False             False
# 4               True                           True             False
# ...              ...                            ...               ...
# 3367            True                           True             False
# 3368           False                          False             False
# 3369           False                          False             False
# 3370           False                          False             False
# 3371           False                          False             False
#
#       preciom2  criminality_ratio  mean_price_munimadrid  \
# 0         2150           0.179886              4170.1250
# 1         3921           0.179886              4170.1250
# 2         2150           0.179886              4170.1250
# 3         3921           0.179886              4170.1250
# 4         4000           0.179886              4170.1250
# ...        ...                ...                    ...
# 3367      1292           0.400260              2104.0625
# 3368      1496           0.400260              2104.0625
# 3369      1409           0.400260              2104.0625
# 3370      1676           0.400260              2104.0625
# 3371      1512           0.400260              2104.0625
#
#       education_centers_ratio
# 0                    0.369496
# 1                    0.369496
# 2                    0.369496
# 3                    0.369496
# 4                    0.369496
# ...                       ...
# 3367                 0.414555
# 3368                 0.414555
# 3369                 0.414555
# 3370                 0.414555
# 3371                 0.414555
#
# [3372 rows x 27 columns]

# %% [markdown]
# ### Export final df to excel for later train, test, split.

# %%
df.to_excel("../output/project_dataset.xls")
