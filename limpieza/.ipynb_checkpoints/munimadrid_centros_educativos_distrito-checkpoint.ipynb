# %%
##Importing required libraries
import requests
import pandas as pd
import json
from pandas.io.json import json_normalize

# %% [markdown]
# ### Centros educativos list from munimadrid website

# %%
import sys  
sys.path.append('C:/Users/pinil/Project_idealista\src')
import apis

# %%
from apis import api_centros

# %%
url = "https://datos.madrid.es/egob/catalogo/212790-0-centros-educacion.json"
api_centros(url)
# Out:
# C:/Users/pinil/Project_idealista\src\apis.py:17: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   df = json_normalize(colegios)
#                                                     @id  \
# 0     https://datos.madrid.es/egob/catalogo/tipo/ent...
# 1     https://datos.madrid.es/egob/catalogo/tipo/ent...
# 2     https://datos.madrid.es/egob/catalogo/tipo/ent...
# 3     https://datos.madrid.es/egob/catalogo/tipo/ent...
# 4     https://datos.madrid.es/egob/catalogo/tipo/ent...
# ...                                                 ...
# 1450  https://datos.madrid.es/egob/catalogo/tipo/ent...
# 1451  https://datos.madrid.es/egob/catalogo/tipo/ent...
# 1452  https://datos.madrid.es/egob/catalogo/tipo/ent...
# 1453  https://datos.madrid.es/egob/catalogo/tipo/ent...
# 1454  https://datos.madrid.es/egob/catalogo/tipo/ent...
#
#                                                   @type        id  \
# ...

# %%
df=pd.read_excel("../input/centros_educativos_final.xls")

# %% [markdown]
# ### drop not usefull columns

# %%
df.drop(['@id', '@type', 'id', 'relation',
             'address.area.@id', 'organization.organization-desc',
             'organization.schedule', 'organization.accesibility','Unnamed: 0', 'organization.services']
            , axis=1, inplace=True)

# %%
df
# Out:
#                                                   title  \
# 0                                Academia Darío Estudio
# 1                         Altair, Colegio Internacional
# 2     Aula Municipal de Formación de Personas Adulta...
# 3     Aula Municipal de Formación de Personas Adulta...
# 4     Aula Municipal de Formación de Personas Adulta...
# ...                                                 ...
# 1450          Organización Profesional Española (OPESA)
# 1451            Real Colegio Santa Isabel - La Asunción
# 1452           San Román Escuela de Estudios Superiores
# 1453  Sanromán Centro Internacional de Estudios Prof...
# 1454                      Trainek formación profesional
#
#                                    address.district.@id address.locality  \
# 0     https://datos.madrid.es/egob/kos/Provincia/Mad...           MADRID
# 1     https://datos.madrid.es/egob/kos/Provincia/Mad...           MADRID
# ...

# %% [markdown]
# ### Export file to excel for later merge to idealista dataframe

# %%
df.to_excel("../input/centros_educativos_final.xls")
