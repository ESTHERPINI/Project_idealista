# %%
#importing libraries
import pandas as pd

# %%
df_tts=pd.read_excel("../Idealista/project_dataset.xls")
df_tts
# Out:
#       Unnamed: 0  propertyCode  numPhotos floor   price propertyType  \
# 0              0      94477419          2     1  114000         flat
# 1              1      94474758          7     1  149000         flat
# 2              2      94477419          2     1  114000         flat
# 3              3      94474758          7     1  149000         flat
# 4              4      94471119         49     1  500000         flat
# ...          ...           ...        ...   ...     ...          ...
# 1603        1603      94304495         25     2  159000         flat
# 1604        1604      94304043          8     2  199000       duplex
# 1605        1605      94303103         25     2  139500         flat
# 1606        1606      94301925         27    bj  119000         flat
# 1607        1607      94300959         10     7  118000         flat
#
#      operation  size  exterior  rooms  ...  hasPlan has3DTour has360  \
# ...
