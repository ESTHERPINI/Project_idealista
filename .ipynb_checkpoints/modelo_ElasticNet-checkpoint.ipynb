# %%
import pandas as pd  
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
import matplotlib.pylab as pylab
import seaborn as sns
import matplotlib.pylab as pylab
from sklearn import metrics
import numpy as np # linear algebra
import pandas as pd # data processing
from sklearn.preprocessing import OneHotEncoder, LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.pipeline import Pipeline
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LinearRegression
from xgboost import XGBRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.model_selection import cross_val_score
from sklearn.metrics import mean_squared_error
from sklearn import metrics
from sklearn.linear_model import Ridge, Lasso
from sklearn.linear_model import SGDRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn import metrics
from sklearn.model_selection import train_test_split
train = pd.read_excel("../Project/output/project_dataset.xls")
train
# Out:
#       Unnamed: 0  propertyCode  numPhotos floor   price propertyType  size  \
# 0              0      94477419          2     1  114000         flat    53
# 1              1      94474758          7     1  149000         flat    38
# 2              2      94477419          2     1  114000         flat    53
# 3              3      94474758          7     1  149000         flat    38
# 4              4      94471119         49     1  500000         flat   125
# ...          ...           ...        ...   ...     ...          ...   ...
# 1515        1515      94304495         25     2  159000         flat   123
# 1516        1516      94304043          8     2  199000       duplex   133
# 1517        1517      94303103         25     2  139500         flat    99
# 1518        1518      94301925         27    bj  119000         flat    71
# 1519        1519      94300959         10     7  118000         flat    78
#
#       exterior  rooms  bathrooms  ... hasLift priceByArea  hasPlan  has3DTour  \
# 0        False      1          1  ...     0.0        2151    False      False
# 1        False      1          1  ...     0.0        3921    False      False
# 2        False      1          1  ...     0.0        2151    False      False
# 3        False      1          1  ...     0.0        3921    False      False
# 4         True      3          2  ...     1.0        4000     True      False
# ...        ...    ...        ...  ...     ...         ...      ...        ...
# 1515      True      2          2  ...     0.0        1293    False      False
# 1516     False      4          2  ...     0.0        1496    False      False
# 1517      True      3          2  ...     1.0        1409    False      False
# 1518     False      3          1  ...     0.0        1676    False      False
# 1519      True      2          1  ...     1.0        1513    False      False
#
#       has360  parking  preciom2 criminality_ratio  mean_price_munimadrid  \
# 0      False    False      2150          0.186693              4170.1250
# 1      False    False      3921          0.186693              4170.1250
# 2      False    False      2150          0.186693              4170.1250
# 3      False    False      3921          0.186693              4170.1250
# 4      False     True      4000          0.186693              4170.1250
# ...      ...      ...       ...               ...                    ...
# 1515    True     True      1292          0.400260              2104.0625
# 1516   False    False      1496          0.400260              2104.0625
# 1517   False    False      1409          0.400260              2104.0625
# 1518   False    False      1676          0.400260              2104.0625
# 1519   False    False      1512          0.400260              2104.0625
#
#       education_centers_ratio
# 0                    0.369496
# 1                    0.369496
# 2                    0.369496
# 3                    0.369496
# 4                    0.369496
# ...                       ...
# 1515                 0.414555
# 1516                 0.414555
# 1517                 0.414555
# 1518                 0.414555
# 1519                 0.414555
#
# [1520 rows x 29 columns]

# %%
train.drop(columns = ['Unnamed: 0'], inplace = True)

# %%
len(train)
# Out:
# 1520

# %%
train.isnull().sum()
# Out:
# propertyCode               0
# numPhotos                  0
# floor                      0
# price                      0
# propertyType               0
# size                       0
# exterior                   0
# rooms                      0
# bathrooms                  0
# address                    0
# district                   0
# latitude                   0
# longitude                  0
# showAddress                0
# distance                   0
# hasVideo                   0
# status                     0
# newDevelopment             0
# hasLift                    0
# priceByArea                0
# hasPlan                    0
# has3DTour                  0
# has360                     0
# parking                    0
# preciom2                   0
# criminality_ratio          0
# mean_price_munimadrid      0
# education_centers_ratio    0
# dtype: int64

# %%
train.describe()
# Out:
#        propertyCode    numPhotos         price         size        rooms  \
# count  1.520000e+03  1520.000000  1.520000e+03  1520.000000  1520.000000
# price                     0.069942 -0.026381  0.154766  0.676203
# size                      0.062124 -0.011852  0.255665  0.290454
# exterior                  0.054882 -0.044315  0.180396 -0.054078
# rooms                    -0.016725 -0.013013  0.078341 -0.084787
# bathrooms                 0.036800 -0.033269  0.218306  0.349508
# latitude                  0.068824 -0.007696  0.080616  0.481668
# longitude                 0.057099 -0.014292  0.112100  0.300170
# showAddress              -0.030379 -0.067151  0.009793  0.142186
# distance                  0.012688 -0.017363  0.207912 -0.564601
# hasVideo                  0.096554 -0.023960  0.084668  0.061593
# newDevelopment           -0.023305 -0.037027  0.097148  0.222449
# hasLift                   0.051778 -0.026226  0.259321  0.340005
# priceByArea               0.081177 -0.018776  0.082070  1.000000
# hasPlan                   0.158442  0.187838  0.054410  0.132845
# has3DTour                 1.000000 -0.049583  0.019347  0.081170
# has360                   -0.049583  1.000000  0.018769 -0.018777
# parking                   0.019347  0.018769  1.000000  0.082074
# preciom2                  0.081170 -0.018777  0.082074  1.000000
# criminality_ratio         0.024348  0.003843 -0.164867  0.485847
# mean_price_munimadrid     0.050987 -0.007318 -0.046390  0.775454
# education_centers_ratio   0.059316 -0.039826  0.179157 -0.111121
#
#                          criminality_ratio  mean_price_munimadrid  \
# propertyCode                      0.048034               0.031153
# numPhotos                         0.044524               0.070728
# price                             0.198525               0.423965
# size                              0.045115               0.190817
# exterior                         -0.138337              -0.183885
# rooms                            -0.139987              -0.105422
# bathrooms                         0.101964               0.223441
# latitude                          0.272961               0.606747
# longitude                         0.014417               0.383893
# showAddress                       0.086914               0.133758
# distance                         -0.559961              -0.674309
# hasVideo                          0.066917               0.039879
# newDevelopment                    0.026639               0.080934
# hasLift                          -0.015635               0.228426
# priceByArea                       0.485841               0.775459
# hasPlan                           0.083203               0.120401
# has3DTour                         0.024348               0.050987
# has360                            0.003843              -0.007318
# parking                          -0.164867              -0.046390
# preciom2                          0.485847               0.775454
# criminality_ratio                 1.000000               0.681588
# mean_price_munimadrid             0.681588               1.000000
# education_centers_ratio          -0.162800              -0.096179
#
#                          education_centers_ratio
# propertyCode                           -0.029533
# numPhotos                               0.010647
# price                                  -0.019929
# size                                    0.058890
# exterior                                0.168462
# rooms                                   0.058065
# bathrooms                               0.019698
# latitude                                0.402486
# longitude                               0.651612
# showAddress                            -0.003351
# distance                                0.642054
# hasVideo                               -0.010561
# newDevelopment                          0.010771
# hasLift                                 0.057447
# priceByArea                            -0.111122
# hasPlan                                -0.030052
# has3DTour                               0.059316
# has360                                 -0.039826
# parking                                 0.179157
# preciom2                               -0.111121
# criminality_ratio                      -0.162800
# mean_price_munimadrid                  -0.096179
# education_centers_ratio                 1.000000
#
# [23 rows x 23 columns]

# %%
corr_mat = train.corr()
plt.figure(figsize = (16,5))
corr_mat['price'].sort_values(ascending = False).plot(kind = 'bar');

# %%
train.columns
# Out:
# Index(['propertyCode', 'numPhotos', 'floor', 'price', 'propertyType', 'size',
#        'exterior', 'rooms', 'bathrooms', 'address', 'district', 'latitude',
#        'longitude', 'showAddress', 'distance', 'hasVideo', 'status',
#        'newDevelopment', 'hasLift', 'priceByArea', 'hasPlan', 'has3DTour',
#        'has360', 'parking', 'preciom2', 'criminality_ratio',
#        'mean_price_munimadrid', 'education_centers_ratio'],
#       dtype='object')

# %%
num_cols = list(train._get_numeric_data().columns)
print("Numerical columns: ", num_cols)

cat_cols=list(set(train.columns) - set(num_cols))
print("Categorical columns: ", cat_cols)
# Out:
# Numerical columns:  ['propertyCode', 'numPhotos', 'price', 'size', 'exterior', 'rooms', 'bathrooms', 'latitude', 'longitude', 'showAddress', 'distance', 'hasVideo', 'newDevelopment', 'hasLift', 'priceByArea', 'hasPlan', 'has3DTour', 'has360', 'parking', 'preciom2', 'criminality_ratio', 'mean_price_munimadrid', 'education_centers_ratio']
# Categorical columns:  ['status', 'address', 'floor', 'district', 'propertyType']

# %%
train = train.copy()
train = pd.get_dummies(train, prefix=['floor', 'status', 'district', 'address', 'propertyType'])

# %%
columnas_train = [a for a in train.columns if a not in ["price"]]
X = train[columnas_train]
y = train["price"]

# %%
search.fit(X,y)
search.best_params_
# Out:
# C:\Users\pinil\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3060240484365.0137, tolerance: 21099212248.272675
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\pinil\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3123528034166.0415, tolerance: 21120431456.806244
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\pinil\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2792193176764.133, tolerance: 18987483768.0424
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\pinil\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2981508571202.2134, tolerance: 18872564542.055996
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\pinil\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2981063227528.143, tolerance: 19435041833.57517
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\pinil\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3199553608188.903, tolerance: 20997098879.19284
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\pinil\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3199388267341.702, tolerance: 21083370824.794262
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\pinil\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1319644326883.446, tolerance: 10102590912.92255
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\pinil\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3150679406980.008, tolerance: 20788387910.206577
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\pinil\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3050985093187.735, tolerance: 20822885993.531498
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\pinil\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2825561604971.3374, tolerance: 21099212248.272675
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\pinil\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2890835081375.7837, tolerance: 21120431456.806244
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\pinil\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2580763965705.374, tolerance: 18987483768.0424
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\pinil\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2769800329003.767, tolerance: 18872564542.055996
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\pinil\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2767806827201.4316, tolerance: 19435041833.57517
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\pinil\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2968200709053.209, tolerance: 20997098879.19284
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\pinil\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2968374342104.459, tolerance: 21083370824.794262
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\pinil\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1215706313367.5142, tolerance: 10102590912.92255
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\pinil\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2922239173008.919, tolerance: 20788387910.206577
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\pinil\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2815407143376.542, tolerance: 20822885993.531498
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\pinil\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2577870346848.341, tolerance: 21099212248.272675
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\pinil\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2644130292631.1055, tolerance: 21120431456.806244
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\pinil\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2353396310000.0938, tolerance: 18987483768.0424
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\pinil\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2541680613043.1494, tolerance: 18872564542.055996
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\pinil\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2537200772351.386, tolerance: 19435041833.57517
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\pinil\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2723575578956.5884, tolerance: 20997098879.19284
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\pinil\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2724567963598.0776, tolerance: 21083370824.794262
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\pinil\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1105863321380.8389, tolerance: 10102590912.92255
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\pinil\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2681347439509.969, tolerance: 20788387910.206577
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\pinil\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2567801117798.2417, tolerance: 20822885993.531498
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\pinil\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2315308795177.1113, tolerance: 21099212248.272675
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\pinil\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2381401924324.861, tolerance: 21120431456.806244
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\pinil\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2108297186785.3508, tolerance: 18987483768.0424
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\pinil\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2297640208476.8154, tolerance: 18872564542.055996
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\pinil\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2288831081184.3896, tolerance: 19435041833.57517
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\pinil\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2463232278132.707, tolerance: 20997098879.19284
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\pinil\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2465392256578.482, tolerance: 21083370824.794262
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\pinil\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 989075026733.8616, tolerance: 10102590912.92255
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\pinil\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2425742715879.7915, tolerance: 20788387910.206577
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\pinil\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2308306932077.709, tolerance: 20822885993.531498
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\pinil\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3416176193670.996, tolerance: 21521234263.44541
#   model = cd_fast.enet_coordinate_descent(
# {'alpha': 1e-05, 'l1_ratio': 0.2}

# %%
abs(search.best_score_)
# Out:
# 18948747605.851505

# %%
# Assigning the featurs as X and trarget as y

X_train, X_test, y_train, y_test = train_test_split(X, y,test_size=0.25, random_state=7)

# %%
# Building pipelins of standard scaler and model for varios regressors.

pipeline_lr=Pipeline([("scalar1",StandardScaler()),
                     ("lr_classifier",LinearRegression())])

pipeline_dt=Pipeline([("scalar2",StandardScaler()),
                     ("dt_classifier",DecisionTreeRegressor())])

pipeline_rf=Pipeline([("scalar3",StandardScaler()),
                     ("rf_classifier",RandomForestRegressor())])

pipeline_kn=Pipeline([("scalar4",StandardScaler()),
                     ("rf_classifier",KNeighborsRegressor())])

pipeline_xgb=Pipeline([("scalar5",StandardScaler()),
                     ("rf_classifier",XGBRegressor())])

pipeline_ridbe=Pipeline([("scalar6",StandardScaler()),
                     ("rf_classifier",Ridge())])

pipeline_lasso=Pipeline([("scalar7",StandardScaler()),
                     ("rf_classifier",Lasso())])

pipeline_gbr=Pipeline([("scalar8",StandardScaler()),
                     ("rf_classifier",GradientBoostingRegressor())])

# %%
# List of all the pipelines
pipelines = [pipeline_lr, pipeline_dt, pipeline_rf, pipeline_kn, 
             pipeline_xgb, pipeline_ridbe,pipeline_lasso, pipeline_gbr]

# %%
# Dictionary of pipelines and model types for ease of reference
pipe_dict = {0: "LinearRegression", 1: "DecisionTree", 2: "RandomForest",
             3: "KNeighbors", 4: "XGBRegressor", 5:"Ridge", 6:"Lasso",
            7:'GradientBoostingRegressor'}

# %%
# Fit the pipelines
for pipe in pipelines:
    pipe.fit(X_train, y_train)
# Out:
# C:\Users\pinil\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1523329730743.846, tolerance: 18238222790.392853
#   model = cd_fast.enet_coordinate_descent(

# %%
cv_results_rms = []
for i, model in enumerate(pipelines):
    cv_score = cross_val_score(model, X_train,y_train,scoring="neg_root_mean_squared_error", cv=10)
    cv_results_rms.append(cv_score)
    print("%s: %f " % (pipe_dict[i], cv_score.mean()))
# Out:
# LinearRegression: -4520546484538222080.000000
# DecisionTree: -121148.457495
# RandomForest: -91304.842662
# KNeighbors: -356177.323939
# XGBRegressor: -100367.479522
# Ridge: -121372.255810
# C:\Users\pinil\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1341667322943.0552, tolerance: 16974807222.986029
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\pinil\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1333541897114.6018, tolerance: 14640409807.455154
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\pinil\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1297681174402.1243, tolerance: 17180141812.453224
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\pinil\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1284705459510.3027, tolerance: 15831973868.211847
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\pinil\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1421230432496.457, tolerance: 17522488508.985474
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\pinil\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 551469774839.3398, tolerance: 15273562459.94494
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\pinil\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1351966605099.432, tolerance: 17106092618.960632
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\pinil\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1411852166411.2205, tolerance: 17671227506.36182
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\pinil\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1334437820959.3691, tolerance: 16186971549.457289
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\pinil\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1390309528268.416, tolerance: 15737371289.539288
#   model = cd_fast.enet_coordinate_descent(
# Lasso: -133458.845267
# GradientBoostingRegressor: -81466.806724

# %%
for i, model in enumerate(pipelines):
    pred = model.predict(X_test)
    print(pipelines[i],"R^2:",metrics.r2_score(y_test, pred))
    print("Adjusted R^2:",1 - (1-metrics.r2_score(y_test, pred))*(len(y_test)-1)/(len(y_test)-X_test.shape[1]-1))
    print("MAE:",metrics.mean_absolute_error(y_test, pred))
    print("MSE:",metrics.mean_squared_error(y_test, pred))
    print("RMSE:",np.sqrt(metrics.mean_squared_error(y_test, pred)))
# Out:
# Pipeline(steps=[('scalar1', StandardScaler()),
#                 ('lr_classifier', LinearRegression())]) R^2: -7.6474320404349055e+25
# Adjusted R^2: 4.8306279055413815e+25
# MAE: 1.2710620859311716e+18
# MSE: 6.60551658380785e+36
# RMSE: 2.570119955139808e+18
# Pipeline(steps=[('scalar2', StandardScaler()),
#                 ('dt_classifier', DecisionTreeRegressor())]) R^2: 0.9273240779239917
# Adjusted R^2: 1.0459069574446787
# MAE: 26078.844736842104
# MSE: 6277427585.865789
# RMSE: 79230.21889320886
# Pipeline(steps=[('scalar3', StandardScaler()),
#                 ('rf_classifier', RandomForestRegressor())]) R^2: 0.9736220571699267
# Adjusted R^2: 1.0166620672209963
# MAE: 14087.462815789473
# MSE: 2278411078.248378
# RMSE: 47732.704493338504
# Pipeline(steps=[('scalar4', StandardScaler()),
#                 ('rf_classifier', KNeighborsRegressor())]) R^2: -0.08680364862982803
# Adjusted R^2: 1.6864976380511747
# MAE: 254754.11263157893
# MSE: 93873335341.97643
# RMSE: 306387.55742029805
# Pipeline(steps=[('scalar5', StandardScaler()),
#                 ('rf_classifier',
#                  XGBRegressor(base_score=0.5, booster='gbtree',
#                               colsample_bylevel=1, colsample_bynode=1,
#                               colsample_bytree=1, gamma=0, gpu_id=-1,
#                               importance_type='gain',
#                               interaction_constraints='',
#                               learning_rate=0.300000012, max_delta_step=0,
#                               max_depth=6, min_child_weight=1, missing=nan,
#                               monotone_constraints='()', n_estimators=100,
#                               n_jobs=8, num_parallel_tree=1, random_state=0,
#                               reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#                               subsample=1, tree_method='exact',
#                               validate_parameters=1, verbosity=None))]) R^2: 0.9637074452947394
# Adjusted R^2: 1.0229247970554896
# MAE: 17066.092351973683
# MSE: 3134791792.941768
# RMSE: 55989.21139774848
# Pipeline(steps=[('scalar6', StandardScaler()), ('rf_classifier', Ridge())]) R^2: 0.8466620085259486
# Adjusted R^2: 1.0968584979477758
# MAE: 82068.30152720341
# MSE: 13244663571.433733
# RMSE: 115085.46203336776
# Pipeline(steps=[('scalar7', StandardScaler()), ('rf_classifier', Lasso())]) R^2: 0.8004338266055201
# Adjusted R^2: 1.1260592995275132
# MAE: 94684.18254419889
# MSE: 17237651292.019096
# RMSE: 131292.23622141217
# Pipeline(steps=[('scalar8', StandardScaler()),
#                 ('rf_classifier', GradientBoostingRegressor())]) R^2: 0.9822165917526436
# Adjusted R^2: 1.01123318620958
# MAE: 15822.782129415811
# MSE: 1536052853.734903
# RMSE: 39192.51017394654

# %%
pred = pipeline_gbr.predict(X_test)
print("R^2:",metrics.r2_score(y_test, pred))
print("Adjusted R^2:",1 - (1-metrics.r2_score(y_test, pred))*(len(y_test)-1)/(len(y_test)-X_test.shape[1]-1))
print("MAE:",metrics.mean_absolute_error(y_test, pred))
print("MSE:",metrics.mean_squared_error(y_test, pred))
print("RMSE:",np.sqrt(metrics.mean_squared_error(y_test, pred)))
# Out:
# R^2: 0.9822165917526436
# Adjusted R^2: 1.01123318620958
# MAE: 15822.782129415811
# MSE: 1536052853.734903
# RMSE: 39192.51017394654

# %%
df = pd.DataFrame({'Actual': y_test, 'Predicted': pred})
df
# Out:
#        Actual     Predicted
# 1167  1200000  1.191614e+06
# 881    165000  1.694698e+05
# 1078   340000  3.311383e+05
# 465    835000  8.014802e+05
# 1386   801800  7.941737e+05
# ...       ...           ...
# 1455   139000  1.654821e+05
# 915    115000  1.162652e+05
# 895    129900  1.323174e+05
# 595    860000  8.573117e+05
# 742    247000  2.319927e+05
#
# [380 rows x 2 columns]

# %%
df1 = df.head(25)
df1.plot(kind='bar',figsize=(16,10))
plt.grid(which='major', linestyle='-', linewidth='0.5', color='green')
plt.grid(which='minor', linestyle=':', linewidth='0.5', color='black')
plt.show()
