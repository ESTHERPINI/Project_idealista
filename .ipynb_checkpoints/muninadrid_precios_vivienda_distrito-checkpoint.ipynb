# %%
#importing required library
import pandas as pd
import requests

# %% [markdown]
# ### We will get the real state prices by district on Madrid from the munimadrid website

# %% [markdown]
# [Munimadrid URL link](https://www.madrid.es/UnidadesDescentralizadas/UDCEstadistica/Nuevaweb/Edificaci%C3%B3n%20y%20Vivienda/Mercado%20de%20la%20Vivienda/Precios%20de%20la%20Vivienda/Distritos/E3320121.xls)

# %%
url="https://www.madrid.es/UnidadesDescentralizadas/UDCEstadistica/Nuevaweb/Edificaci%C3%B3n%20y%20Vivienda/Mercado%20de%20la%20Vivienda/Precios%20de%20la%20Vivienda/Distritos/E3320121.xls"

# %% [markdown]
# #### we call a function to import a excel file with a request

# %%
#from src.apis import import_excel

# %%
#import_excel(url)

# %%
viviendas="https://www.madrid.es/UnidadesDescentralizadas/UDCEstadistica/Nuevaweb/Edificaci%C3%B3n%20y%20Vivienda/Mercado%20de%20la%20Vivienda/Precios%20de%20la%20Vivienda/Distritos/E3320121.xls"
resp = requests.get(viviendas)

output = open('evolucion_precio_vivienda.xls', 'wb')
output.write(resp.content)
output.close()    

file = "evolucion_precio_vivienda.xls"
evolucion_precio_vivienda = pd.read_excel(file, header=[5]) #reading file
evolucion_precio_vivienda.head()
# Out:
#    Unnamed: 0          Distrito    Mayo   Abril   Marzo  Febrero   Enero  \
# 0         NaN               NaN     NaN     NaN     NaN      NaN     NaN
# 1         NaN  Ciudad de Madrid  3746.0  3716.0  3712.0   3687.0  2867.0
# 2         NaN               NaN     NaN     NaN     NaN      NaN     NaN
# 3         NaN        01. Centro  4802.0  4809.0  4849.0   4830.0  4841.0
# 4         NaN    02. Arganzuela  4000.0  3932.0  3942.0   3915.0  3915.0
#
#    Unnamed: 7  Diciembre  Noviembre  Octubre  Septiembre  Agosto   Julio  \
# 0         NaN        NaN        NaN      NaN         NaN     NaN     NaN
# 1         NaN     3682.0     3664.0   3652.0      3665.0  3681.0  3687.0
# 2         NaN        NaN        NaN      NaN         NaN     NaN     NaN
# 3         NaN     4865.0     4878.0   4909.0      4934.0  4963.0  4981.0
# 4         NaN     3888.0     3917.0   3908.0      3915.0  3912.0  3910.0
#
#     Junio  Mayo.1  Abril.1  Marzo.1  Febrero.1  Enero.1
# ...

# %%
df=evolucion_precio_vivienda.copy()
df.head()
# Out:
#    Unnamed: 0          Distrito    Mayo   Abril   Marzo  Febrero   Enero  \
# 0         NaN               NaN     NaN     NaN     NaN      NaN     NaN
# 1         NaN  Ciudad de Madrid  3746.0  3716.0  3712.0   3687.0  2867.0
# 2         NaN               NaN     NaN     NaN     NaN      NaN     NaN
# 3         NaN        01. Centro  4802.0  4809.0  4849.0   4830.0  4841.0
# 4         NaN    02. Arganzuela  4000.0  3932.0  3942.0   3915.0  3915.0
#
#    Unnamed: 7  Diciembre  Noviembre  Octubre  Septiembre  Agosto   Julio  \
# 0         NaN        NaN        NaN      NaN         NaN     NaN     NaN
# 1         NaN     3682.0     3664.0   3652.0      3665.0  3681.0  3687.0
# 2         NaN        NaN        NaN      NaN         NaN     NaN     NaN
# 3         NaN     4865.0     4878.0   4909.0      4934.0  4963.0  4981.0
# 4         NaN     3888.0     3917.0   3908.0      3915.0  3912.0  3910.0
#
#     Junio  Mayo.1  Abril.1  Marzo.1  Febrero.1  Enero.1
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Distrito', 'Mayo', 'Abril', 'Marzo', 'Febrero', 'Enero',
#        'Unnamed: 7', 'Diciembre', 'Noviembre', 'Octubre', 'Septiembre',
#        'Agosto', 'Julio', 'Junio', 'Mayo.1', 'Abril.1', 'Marzo.1', 'Febrero.1',
#        'Enero.1'],
#       dtype='object')

# %% [markdown]
# #### we drop blank columns and rows

# %%
df.drop(["Unnamed: 0", "Unnamed: 7"],axis=1, inplace=True)

# %%
df.drop([0,1,2, 23, 24,25],axis=0, inplace=True)

# %%
df.head()
# Out:
#          Distrito    Mayo   Abril   Marzo  Febrero   Enero  Diciembre  \
# 3      01. Centro  4802.0  4809.0  4849.0   4830.0  4841.0     4865.0
# 4  02. Arganzuela  4000.0  3932.0  3942.0   3915.0  3915.0     3888.0
# 5      03. Retiro  4692.0  4583.0  4584.0   4537.0  4496.0     4502.0
# 6   04. Salamanca  5949.0  5933.0  5914.0   5807.0  5789.0     5740.0
# 7   05. Chamartín  5115.0  5097.0  5084.0   5056.0  5020.0     4999.0
#
#    Noviembre  Octubre  Septiembre  Agosto   Julio   Junio  Mayo.1  Abril.1  \
# 3     4878.0   4909.0      4934.0  4963.0  4981.0  5061.0  5075.0   5062.0
# 4     3917.0   3908.0      3915.0  3912.0  3910.0  3948.0  3962.0   3903.0
# 5     4520.0   4517.0      4548.0  4514.0  4513.0  4564.0  4586.0   4560.0
# 6     5747.0   5808.0      5826.0  5833.0  5903.0  5986.0  5985.0   5893.0
# 7     5018.0   5040.0      5056.0  5068.0  5109.0  5180.0  5179.0   5143.0
#
#    Marzo.1  Febrero.1  Enero.1
# 3   5026.0     5088.0   5096.0
# ...

# %% [markdown]
# ### new columns names

# %%
df = df.rename(columns={'Mayo':2021_05, 'Abril':202104, 'Marzo':202103, 'Febrero':202102,
                       'Enero':202101,'Diciembre':202012, "Noviembre":202011, "Octubre":202010,
                        "Septiembre":202009, "Agosto": 202008, "Julio":202007, "Junio":202007,
                        "Mayo.1": 202005, "Abril.1":202004, "Marzo.1":202003, "Febrero.1": 202002,
                        "Enero.1":202001})
df.columns
# Out:
# Index(['Distrito',     202105,     202104,     202103,     202102,     202101,
#            202012,     202011,     202010,     202009,     202008,     202007,
#            202007,     202005,     202004,     202003,     202002,     202001],
#       dtype='object')

# %%
df.head()
# Out:
#          Distrito  202105  202104  202103  202102  202101  202012  202011  \
# 3      01. Centro  4802.0  4809.0  4849.0  4830.0  4841.0  4865.0  4878.0
# 4  02. Arganzuela  4000.0  3932.0  3942.0  3915.0  3915.0  3888.0  3917.0
# 5      03. Retiro  4692.0  4583.0  4584.0  4537.0  4496.0  4502.0  4520.0
# 6   04. Salamanca  5949.0  5933.0  5914.0  5807.0  5789.0  5740.0  5747.0
# 7   05. Chamartín  5115.0  5097.0  5084.0  5056.0  5020.0  4999.0  5018.0
#
#    202010  202009  202008  202007  202007  202005  202004  202003  202002  \
# 3  4909.0  4934.0  4963.0  4981.0  5061.0  5075.0  5062.0  5026.0  5088.0
# 4  3908.0  3915.0  3912.0  3910.0  3948.0  3962.0  3903.0  3878.0  3894.0
# 5  4517.0  4548.0  4514.0  4513.0  4564.0  4586.0  4560.0  4555.0  4549.0
# 6  5808.0  5826.0  5833.0  5903.0  5986.0  5985.0  5893.0  5815.0  5786.0
# 7  5040.0  5056.0  5068.0  5109.0  5180.0  5179.0  5143.0  5118.0  5105.0
#
#    202001
# 3  5096.0
# 4  3983.0
# 5  4572.0
# 6  5872.0
# 7  5070.0

# %%
df.tail()
# Out:
#                    Distrito  202105  202104  202103  202102  202101  202012  \
# 18            16. Hortaleza  3754.0  3688.0  3647.0  3665.0  3660.0  3668.0
# 19           17. Villaverde  1721.0  1707.0  1717.0  1701.0  1692.0  1706.0
# 20       18. Villa Vallecas  2313.0  2307.0  2320.0  2343.0  2396.0  2384.0
# 21            19. Vicálvaro  2438.0  2451.0  2417.0  2374.0  2354.0  2318.0
# 22  20. San Blas-Canillejas  2520.0  2554.0  2573.0  2528.0  2501.0  2558.0
#
#     202011  202010  202009  202008  202007  202007  202005  202004  202003  \
# 18  3641.0  3583.0  3601.0  3646.0  3711.0  3710.0  3714.0  3759.0  3738.0
# 19  1714.0  1716.0  1712.0  1709.0  1707.0  1707.0  1728.0  1727.0  1734.0
# 20  2376.0  2363.0  2389.0  2413.0  2461.0  2471.0  2437.0  2366.0  2367.0
# 21  2322.0  2324.0  2323.0  2303.0  2296.0  2331.0  2350.0  2334.0  2322.0
# 22  2570.0  2538.0  2538.0  2511.0  2482.0  2446.0  2497.0  2517.0  2499.0
#
#     202002  202001
# 18  3737.0  3688.0
# ...

# %%
df.columns
# Out:
# Index(['Distrito',     202105,     202104,     202103,     202102,     202101,
#            202012,     202011,     202010,     202009,     202008,     202007,
#            202007,     202005,     202004,     202003,     202002,     202001],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 20 entries, 3 to 22
# Data columns (total 18 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Distrito  20 non-null     object
#  1   202105    20 non-null     float64
#  2   202104    20 non-null     float64
#  3   202103    20 non-null     float64
#  4   202102    20 non-null     float64
#  5   202101    20 non-null     float64
#  6   202012    20 non-null     float64
#  7   202011    20 non-null     float64
#  8   202010    20 non-null     float64
#  9   202009    20 non-null     float64
#  10  202008    20 non-null     float64
#  11  202007    20 non-null     float64
#  12  202007    20 non-null     float64
#  13  202005    20 non-null     float64
#  14  202004    20 non-null     float64
#  15  202003    20 non-null     float64
#  16  202002    20 non-null     float64
#  17  202001    20 non-null     float64
# dtypes: float64(17), object(1)
# memory usage: 3.0+ KB

# %%
Distrito_list=df.Distrito.to_list()
Distrito_list
# Out:
# ['01. Centro',
#  '02. Arganzuela',
#  '03. Retiro',
#  '04. Salamanca',
#  '05. Chamartín',
#  '06. Tetuán',
#  '07. Chamberí',
#  '08. Fuencarral-El Pardo',
#  '09. Moncloa-Aravaca',
#  '10. Latina',
#  '11. Carabanchel',
#  '12. Usera',
#  '13. Puente Vallecas',
#  '14. Moratalaz',
#  '15. Ciudad Lineal',
#  '16. Hortaleza',
#  '17. Villaverde',
#  '18. Villa Vallecas',
#  '19. Vicálvaro',
#  '20. San Blas-Canillejas']

# %%
df.set_index('Distrito',inplace=True)
#df.transpose()
#df_trasp=df.transpose () 
#df_trasp
df
# Out:
#                          202105  202104  202103  202102  202101  202012  \
# Distrito
# 01. Centro               4802.0  4809.0  4849.0  4830.0  4841.0  4865.0
# 02. Arganzuela           4000.0  3932.0  3942.0  3915.0  3915.0  3888.0
# 03. Retiro               4692.0  4583.0  4584.0  4537.0  4496.0  4502.0
# 04. Salamanca            5949.0  5933.0  5914.0  5807.0  5789.0  5740.0
# 05. Chamartín            5115.0  5097.0  5084.0  5056.0  5020.0  4999.0
# 06. Tetuán               3637.0  3648.0  3658.0  3673.0  3663.0  3649.0
# 07. Chamberí             5248.0  5241.0  5251.0  5247.0  5255.0  5283.0
# 08. Fuencarral-El Pardo  3518.0  3521.0  3509.0  3466.0  3466.0  3491.0
# 09. Moncloa-Aravaca      4004.0  3969.0  3970.0  3977.0  3947.0  3912.0
# 10. Latina               2265.0  2257.0  2239.0  2223.0  2236.0  2246.0
# 11. Carabanchel          2155.0  2104.0  2098.0  2112.0  2141.0  2165.0
# 12. Usera                1975.0  1966.0  1934.0  1932.0  1958.0  1942.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 20 entries, 01. Centro to 20. San Blas-Canillejas
# Data columns (total 17 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   202105  20 non-null     float64
#  1   202104  20 non-null     float64
#  2   202103  20 non-null     float64
#  3   202102  20 non-null     float64
#  4   202101  20 non-null     float64
#  5   202012  20 non-null     float64
#  6   202011  20 non-null     float64
#  7   202010  20 non-null     float64
#  8   202009  20 non-null     float64
#  9   202008  20 non-null     float64
#  10  202007  20 non-null     float64
#  11  202007  20 non-null     float64
#  12  202005  20 non-null     float64
#  13  202004  20 non-null     float64
#  14  202003  20 non-null     float64
#  15  202002  20 non-null     float64
#  16  202001  20 non-null     float64
# dtypes: float64(17)
# memory usage: 2.8+ KB

# %% [markdown]
# ### new column with the mean price by district

# %%
df['mean_price_munimadrid'] = df.sum(axis=1)/(len(df.columns)-1)

# %%
df.head()
# Out:
#                 202105  202104  202103  202102  202101  202012  202011  \
# Distrito
# 01. Centro      4802.0  4809.0  4849.0  4830.0  4841.0  4865.0  4878.0
# 02. Arganzuela  4000.0  3932.0  3942.0  3915.0  3915.0  3888.0  3917.0
# 03. Retiro      4692.0  4583.0  4584.0  4537.0  4496.0  4502.0  4520.0
# 04. Salamanca   5949.0  5933.0  5914.0  5807.0  5789.0  5740.0  5747.0
# 05. Chamartín   5115.0  5097.0  5084.0  5056.0  5020.0  4999.0  5018.0
#
#                 202010  202009  202008  202007  202007  202005  202004  \
# Distrito
# 01. Centro      4909.0  4934.0  4963.0  4981.0  5061.0  5075.0  5062.0
# 02. Arganzuela  3908.0  3915.0  3912.0  3910.0  3948.0  3962.0  3903.0
# 03. Retiro      4517.0  4548.0  4514.0  4513.0  4564.0  4586.0  4560.0
# 04. Salamanca   5808.0  5826.0  5833.0  5903.0  5986.0  5985.0  5893.0
# 05. Chamartín   5040.0  5056.0  5068.0  5109.0  5180.0  5179.0  5143.0
#
#                 202003  202002  202001  mean_price_munimadrid
# Distrito
# ...

# %%
df.columns[:-1]
# Out:
# Index([202105, 202104, 202103, 202102, 202101, 202012, 202011, 202010, 202009,
#        202008, 202007, 202007, 202005, 202004, 202003, 202002, 202001],
#       dtype='object')

# %% [markdown]
# #### drop columns

# %%
df.drop(df.columns[:-1],axis=1, inplace=True)

# %%
df.head(3)
# Out:
#                 mean_price_munimadrid
# Distrito
# 01. Centro                  5254.3125
# 02. Arganzuela              4170.1250
# 03. Retiro                  4837.0000

# %%
df['Distrito'] = df.index 
df
# Out:
#                          mean_price_munimadrid                 Distrito
# Distrito
# 01. Centro                           5254.3125               01. Centro
# 02. Arganzuela                       4170.1250           02. Arganzuela
# 03. Retiro                           4837.0000               03. Retiro
# 04. Salamanca                        6224.1250            04. Salamanca
# 05. Chamartín                        5403.5625            05. Chamartín
# 06. Tetuán                           3899.9375               06. Tetuán
# 07. Chamberí                         5657.3125             07. Chamberí
# 08. Fuencarral-El Pardo              3736.8750  08. Fuencarral-El Pardo
# 09. Moncloa-Aravaca                  4178.1250      09. Moncloa-Aravaca
# 10. Latina                           2422.8750               10. Latina
# 11. Carabanchel                      2289.8750          11. Carabanchel
# 12. Usera                            2104.0625                12. Usera
# ...

# %% [markdown]
# ### plot the price by district

# %%
import plotly
plotly.offline.init_notebook_mode(connected=True)
import plotly.graph_objs as go
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
import plotly.express as px

# %%
ax=df.plot(figsize=(16,4), marker = 'o',linestyle = 'dotted');
# Out:
# C:\Users\pinil\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\core.py:1192: UserWarning:
#
# FixedFormatter should only be used together with FixedLocator

# %% [markdown]
# ### rename district names as per idealista df for later merge

# %%
#Para poder mergear con la tabla de idealista comprobamos que el nombre de los distritos es igual en ambas tablas
district_idealista=pd.read_excel("../Project_idealista/output/tabla_district.xls")
district_idealista_list=list(district_idealista.district.unique())
ordenados_idealista=sorted(district_idealista_list)
print(ordenados_idealista)
# Out:
# ['Arganzuela', 'Barrio de Salamanca', 'Carabanchel', 'Centro', 'Chamartín', 'Chamberí', 'Ciudad Lineal', 'Fuencarral', 'Hortaleza', 'Latina', 'Moncloa', 'Moratalaz', 'Puente de Vallecas', 'Retiro', 'San Blas', 'Tetuán', 'Usera', 'Vicálvaro', 'Villa de Vallecas', 'Villaverde']

# %%
#ordenados_idealista.append("Barajas")
#ordenados_idealista=sorted(ordenados_idealista)

# %%
distrito_promedio_precio=sorted(list(df.Distrito))
print(distrito_promedio_precio)
# Out:
# ['01. Centro', '02. Arganzuela', '03. Retiro', '04. Salamanca', '05. Chamartín', '06. Tetuán', '07. Chamberí', '08. Fuencarral-El Pardo', '09. Moncloa-Aravaca', '10. Latina', '11. Carabanchel', '12. Usera', '13. Puente Vallecas', '14. Moratalaz', '15. Ciudad Lineal', '16. Hortaleza', '17. Villaverde', '18. Villa Vallecas', '19. Vicálvaro', '20. San Blas-Canillejas']

# %%
distrito_promedio_precio=sorted(list(df.Distrito))
print(distrito_promedio_precio)
# Out:
# ['01. Centro', '02. Arganzuela', '03. Retiro', '04. Salamanca', '05. Chamartín', '06. Tetuán', '07. Chamberí', '08. Fuencarral-El Pardo', '09. Moncloa-Aravaca', '10. Latina', '11. Carabanchel', '12. Usera', '13. Puente Vallecas', '14. Moratalaz', '15. Ciudad Lineal', '16. Hortaleza', '17. Villaverde', '18. Villa Vallecas', '19. Vicálvaro', '20. San Blas-Canillejas']

# %%
df.Distrito = df.Distrito.apply(lambda x: (x[4:]))
  
# displaying the data frame
df
# Out:
#                          mean_price_munimadrid             Distrito
# Distrito
# 01. Centro                           5254.3125               Centro
# 02. Arganzuela                       4170.1250           Arganzuela
# 03. Retiro                           4837.0000               Retiro
# 04. Salamanca                        6224.1250            Salamanca
# 05. Chamartín                        5403.5625            Chamartín
# 06. Tetuán                           3899.9375               Tetuán
# 07. Chamberí                         5657.3125             Chamberí
# 08. Fuencarral-El Pardo              3736.8750  Fuencarral-El Pardo
# 09. Moncloa-Aravaca                  4178.1250      Moncloa-Aravaca
# 10. Latina                           2422.8750               Latina
# 11. Carabanchel                      2289.8750          Carabanchel
# 12. Usera                            2104.0625                Usera
# 13. Puente Vallecas                  2028.6250      Puente Vallecas
# ...

# %%
df['Distrito'] = df['Distrito'].replace('Salamanca','Barrio de Salamanca')

# %%
distrito_promedio_precio=sorted(list(df.Distrito))
print(distrito_promedio_precio)
# Out:
# ['Arganzuela', 'Barrio de Salamanca', 'Carabanchel', 'Centro', 'Chamartín', 'Chamberí', 'Ciudad Lineal', 'Fuencarral-El Pardo', 'Hortaleza', 'Latina', 'Moncloa-Aravaca', 'Moratalaz', 'Puente Vallecas', 'Retiro', 'San Blas-Canillejas', 'Tetuán', 'Usera', 'Vicálvaro', 'Villa Vallecas', 'Villaverde']

# %%
conversion_dict= dict(zip(distrito_promedio_precio,ordenados_idealista))
conversion_dict
# Out:
# {'Arganzuela': 'Arganzuela',
#  'Barrio de Salamanca': 'Barrio de Salamanca',
#  'Carabanchel': 'Carabanchel',
#  'Centro': 'Centro',
#  'Chamartín': 'Chamartín',
#  'Chamberí': 'Chamberí',
#  'Ciudad Lineal': 'Ciudad Lineal',
#  'Fuencarral-El Pardo': 'Fuencarral',
#  'Hortaleza': 'Hortaleza',
#  'Latina': 'Latina',
#  'Moncloa-Aravaca': 'Moncloa',
#  'Moratalaz': 'Moratalaz',
#  'Puente Vallecas': 'Puente de Vallecas',
#  'Retiro': 'Retiro',
#  'San Blas-Canillejas': 'San Blas',
#  'Tetuán': 'Tetuán',
#  'Usera': 'Usera',
#  'Vicálvaro': 'Vicálvaro',
#  'Villa Vallecas': 'Villa de Vallecas',
#  'Villaverde': 'Villaverde'}

# %%
df['district'] = df['Distrito'] .replace(conversion_dict)
df.head()
# Out:
#                 mean_price_munimadrid             Distrito  \
# Distrito
# 01. Centro                  5254.3125               Centro
# 02. Arganzuela              4170.1250           Arganzuela
# 03. Retiro                  4837.0000               Retiro
# 04. Salamanca               6224.1250  Barrio de Salamanca
# 05. Chamartín               5403.5625            Chamartín
#
#                            district
# Distrito
# 01. Centro                   Centro
# 02. Arganzuela           Arganzuela
# 03. Retiro                   Retiro
# 04. Salamanca   Barrio de Salamanca
# 05. Chamartín             Chamartín

# %%
df.drop(df.columns[-2],axis=1, inplace=True)

# %%
df.head()
# Out:
#                 mean_price_munimadrid             district
# Distrito
# 01. Centro                  5254.3125               Centro
# 02. Arganzuela              4170.1250           Arganzuela
# 03. Retiro                  4837.0000               Retiro
# 04. Salamanca               6224.1250  Barrio de Salamanca
# 05. Chamartín               5403.5625            Chamartín

# %% [markdown]
# ### saving df for later processing

# %%
# guardando df población/distrito
df.to_excel('../Project_idealista/input/precio_medio_munimadrid.xls')
